# %% [markdown]
# #### Import dependencies

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %%
# Additional necessary imports
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from qiskit_optimization.applications import Maxcut
import dimod
from dwave.system.samplers import DWaveSampler
from dwave.system.composites import EmbeddingComposite

# %%
import gurobipy as gp
from gurobipy import GRB

# %%
import utils
import dwave_utils

# %%
import os
import time
import csv

# %%
import itertools

# %%
import random as rnd

# %% [markdown]
# #### Generate Problem Instance

# %%
def generate_induced_subgraph_game(distribution, n_agents, sparsity=0.0, seed = 123, **kwargs):
    """
    generate_induced_subgraph_game: To generate a . 
    :distribution: distribution function name to sample the edge weights from. (dtype: function) 
    :n_agents: number of agents (dtype: int) 
    :sparsity: describes the connectivity of the graph edges. \
    If 0.0, generates a fully connected graph. \
    If 1.0 generates a connected graph with minimal edges. 
    (dtype: float, range: [0,1]) 
    :returns: induced subgraph game with agents pairs as key and their synergy as float value. 
    (dtype: dictionary) 
    """
    induced_subgraph_game = {}
    #### D: tyring to set a seed to get compareable results
    connected_edges = [(i + 1, j + 1) for i, j in nx.random_tree(n_agents, seed=seed).edges] 
    extra_edges = list(set(itertools.combinations(range(1, n_agents + 1), 2)).difference(connected_edges))
    #### D: seed
    rnd.seed(seed)
    sampled_edges = rnd.sample(extra_edges, int((1 - sparsity) * len(extra_edges)))
    keys = sorted(connected_edges + sampled_edges)
    totalinteractions = len(keys)
    np.random.seed(seed=seed)
    values = distribution(totalinteractions, **kwargs)
    for i, key in enumerate(keys):
        induced_subgraph_game[','.join(map(str, key))] = round(values[i], 2)
    G=nx.Graph()
    G.add_nodes_from(np.arange(0,n_agents,1))
    elist = [tuple((int(x)-1 for x in key.split(',')))+tuple([induced_subgraph_game[key]*-1]) for key in induced_subgraph_game]
    G.add_weighted_edges_from(elist)
    return induced_subgraph_game, G

# %% [markdown]
# #### D-Wave QUBO Solver

# %%
def dwave_solver(linear, quadratic, private_token, runs=10000, **kwargs):
  """
  Solve a binary quadratic model using D-Wave sampler.

  Parameters:
  linear (dict): Linear coefficients of the model.
  quadratic (dict): Quadratic coefficients of the model.
  private_token (str): API token for D-Wave.
  runs (int): Number of reads for the sampler.

  Returns:
  dimod.SampleSet: Sample set returned by D-Wave sampler.
  float: Connection time.
  float: Embedding time.
  float: Response time.
  """
  vartype = dimod.BINARY
  bqm = dimod.BinaryQuadraticModel(linear, quadratic, 0.0, vartype)
  start_time = time.time()
  dwave_sampler = DWaveSampler(token = private_token, solver={'topology__type': 'pegasus'})
  connection_time = time.time() - start_time

  start_time = time.time()
  sampler = EmbeddingComposite(dwave_sampler)
  embedding_time = time.time() - start_time
  start_time = time.time()
  sample_set = sampler.sample(bqm, num_reads=runs)
  response_time = time.time() - start_time
  return sample_set, connection_time, embedding_time, response_time

def annealer_solver(G, private_token, n_samples=2000, **kwargs):
  """
  Solve the Maxcut problem on graph G using a D-Wave annealer.

  Parameters:
  G (networkx.Graph): Graph for which Maxcut is to be solved.
  private_token (str): API token for D-Wave.
  n_samples (int): Number of samples to collect.

  Returns:
  pandas.DataFrame: Dataframe containing samples.
  dict: Dictionary containing information about execution times.
  """
  start_time = time.time()
  w = -1 * nx.adjacency_matrix(G).todense()
  max_cut = Maxcut(w)
  qp = max_cut.to_quadratic_program()
  linear = qp.objective.linear.coefficients.toarray(order=None, out=None)
  quadratic = qp.objective.quadratic.coefficients.toarray(order=None, out=None)
  linear = {int(idx):-round(value,2) for idx,value in enumerate(linear[0])}
  quadratic = {(int(iy),int(ix)):-quadratic[iy, ix] for iy, ix in np.ndindex(quadratic.shape) if iy<ix and abs(quadratic[iy, ix])!=0}
  problem_formulation_time = time.time() - start_time
  sample_set, connection_time, embedding_time, response_time = dwave_solver(linear, quadratic, private_token, runs=n_samples)
  info_dict = sample_set.info['timing'].copy()

  start_time = time.time()
  samples_df = sample_set.to_pandas_dataframe()
  sample_fetch_time = time.time() - start_time

  info_dict['problem_formulation_time'] = problem_formulation_time
  info_dict['connection_time'] = connection_time
  info_dict['embedding_time'] = embedding_time
  info_dict['response_time'] = response_time
  info_dict['sample_fetch_time'] = sample_fetch_time
  return samples_df, info_dict

# %% [markdown]
# #### Gurobi QUBO solver

# %%
def gurobi_qubo_solver(G):
  w = -1 * nx.adjacency_matrix(G).todense()
  max_cut = Maxcut(w)
  qp = max_cut.to_quadratic_program()
  linear = qp.objective.linear.coefficients.toarray(order=None, out=None)
  quadratic = qp.objective.quadratic.coefficients.toarray(order=None, out=None)

  linear = {int(idx):-round(value,2) for idx,value in enumerate(linear[0])}
  quadratic = {(int(iy),int(ix)):-quadratic[iy, ix] for iy, ix in np.ndindex(quadratic.shape) if iy<ix and abs(quadratic[iy, ix])!=0}

  qubo_matrix = np.zeros([len(linear),len(linear)])
  for key,value in linear.items():
    qubo_matrix[int(key),int(key)] = value
  for key,value in quadratic.items():
    qubo_matrix[int(key[0]),int(key[1])] = value/2
    qubo_matrix[int(key[1]),int(key[0])] = value/2

  n = qubo_matrix.shape[0]
  model = gp.Model()
  x = model.addVars(n, vtype=GRB.BINARY)
  obj_expr = gp.quicksum(qubo_matrix[i, j] * x[i] * x[j] for i in range(n) for j in range(n))
  model.setObjective(obj_expr)
  model.setParam('OutputFlag', 0)
  model.optimize()

  if model.status == GRB.OPTIMAL:
    solution = [int(x[i].X) for i in range(n)]
    binary_string = ''.join(str(bit) for bit in solution)
    return binary_string, model.objVal
  else:
    return None, None

# %% [markdown]
# ### D-Wave Advantage Annealer Experiments

# %% [markdown]
# #### Experimental settings

# %%
# seeds = [111,222,333,444,555]

seed = 333

dwave_annealer_solver = True#@param {type:"boolean"}
gurobipy_qubo_solver = False#@param {type:"boolean"}

solver_flags = ''.join(map(str,map(int,[dwave_annealer_solver, gurobipy_qubo_solver])))


table_contents = []

# heights = np.arange(2, 51).tolist()
report_filename = 'optimalSplit_report_' + solver_flags + '_' +  str(seed) + '.txt'
report_filename_csv = 'optimalSplit_report_' + solver_flags + '_' +  str(seed) + '.csv'
qputimes_filename = 'optimalSplit_qputimes_' + solver_flags + '_' +  str(seed) + '.csv'

qpu_output_path = os.path.join('singleSplitresults', f'{seed}')

n_samples = 2000

# %%
# Create the directory if it doesn't exist
# os.makedirs('optimalSplitResults', exist_ok=True)

fieldnames = ['n', 'sparsity', 'distribution', 'seed', 'solution_first', 'value_first', 'solution_lowest', 'value_lowest', 'annealer_tte', 'solution_gurobi', 'value_gurobi', 'gurobi_tte']
if not os.path.exists(report_filename_csv):
  with open(report_filename_csv, mode='w', newline='') as report_file:
        writer = csv.DictWriter(report_file, fieldnames=fieldnames)
        # Write the header row
        writer.writeheader()

# %%
# Create the directory if it doesn't exist
os.makedirs(qpu_output_path, exist_ok=True)

fieldnames = ['qpu_sampling_time', 'qpu_anneal_time_per_sample', 'qpu_readout_time_per_sample', 'qpu_access_time', 'qpu_access_overhead_time', 'qpu_programming_time', 'qpu_delay_time_per_sample', 'post_processing_overhead_time', 'total_post_processing_time', 'problem_formulation_time', 'connection_time', 'embedding_time', 'response_time', 'sample_fetch_time', 'n', 'sparsity']
if dwave_annealer_solver and not os.path.exists(qputimes_filename):
  with open(qputimes_filename, mode='w', newline='') as qputime_file:
        writer = csv.DictWriter(qputime_file, fieldnames=fieldnames)
        # Write the header row
        writer.writeheader()

# %%
distributions = [
    # utils.laplace,
    # utils.normal,
    utils.random
]

sparsities = [0.0,0.5,1.0]

seeds = [111,222,333]

n_agents = np.arange(52,521)

# %% [markdown]
# #### Executions

# %%
for seed in seeds:
  for distribution in distributions:
    for sparsity in sparsities:
      if sparsity == 0.0:
        n_agents = np.arange(2,151)
      if sparsity == 0.5:
        n_agents = np.arange(2,161)
      if sparsity == 1.0:
        n_agents = np.arange(2,492)
      for n in n_agents:
        base_path = os.path.join(qpu_output_path, str(seed),f"sparsity{sparsity}")
        os.makedirs(base_path, exist_ok=True)
        print(f'seed: {seed}, number of agents: {n}')
        np.random.seed(seed=seed)
        isg, G = generate_induced_subgraph_game(distribution, n, sparsity=sparsity, seed = seed)
        start_time = time.time()
        if dwave_annealer_solver:
          sample_set_df, info_dict = annealer_solver(G, private_token='xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx', n_samples = n_samples)
          dwave_annealer_tte = (time.time() - start_time)
          print('dwave_annealer_tte',dwave_annealer_tte)
          dwave_annealer_solution_first = ''.join(sample_set_df.iloc[0][:-3].astype(int).astype(str))
          dwave_annealer_solution_most = ''.join(sample_set_df.sort_values(by=['num_occurrences', 'energy'], ascending=[False, True]).iloc[0][:-3].astype(int).astype(str))

          dwave_annealer_value_first = sample_set_df.iloc[0][-2:-1][0]
          dwave_annealer_value_most = sample_set_df.sort_values(by=['num_occurrences', 'energy'], ascending=[False, True]).iloc[0][-2:-1][0]

          print('dwave_annealer_value_lowest_energy',dwave_annealer_value_first)
          print('dwave_annealer_value_most_occurred',dwave_annealer_value_most)

          print("ANNEALER DONE!")
          qputime_dic = info_dict.copy()
          qputime_dic['n'] = n
          qputime_dic['sparsity'] = sparsity
          # qputime_dic['Width'] = width
          print('qputime_dic',qputime_dic)
  
          sample_set_df.to_csv(os.path.join(base_path, f'{n}.csv'), index=False)

          with open(qputimes_filename, mode='a', newline='') as qpu_times_file:
            writer = csv.DictWriter(qpu_times_file, fieldnames=qputime_dic.keys())
            writer.writerow(qputime_dic)
        else:
          dwave_annealer_solution, dwave_annealer_value = None, None
  
  
        start_time = time.time()
        if gurobipy_qubo_solver:
          try:
            gurobi_qubo_solution, gurobi_qubo_value = gurobi_qubo_solver(G)
            gurobi_qubo_tte = (time.time() - start_time)
            print('gurobi_qubo_value',gurobi_qubo_value)
            print('gurobi_qubo_tte:',gurobi_qubo_tte)
            print("GUROBI QUBO DONE!")
          except Exception as e:
            print("Gurobi QUBO execution is unsuccessful due to "+ str(e))
            gurobi_qubo_solution, gurobi_qubo_value = None, None
        else:
          gurobi_qubo_solution, gurobi_qubo_value = None, None

        row = []
        row_d = {}

        row.append(int(n))
        row.append(np.round(sparsity,4))
        row.append(distribution.__name__)
        row.append(seed)


        row_d['n'] = int(n)
        row_d['sparsity'] = np.round(sparsity,4)
        row_d['distribution'] = distribution.__name__
        row_d['seed'] = seed
        # row.append(int(width))

        if dwave_annealer_solver:
          row.append(''.join(map(str, map(int, (dwave_annealer_solution_first)))))
          row.append(np.round(dwave_annealer_value_first,4))
          row.append(''.join(map(str, map(int, (dwave_annealer_solution_most)))))
          row.append(np.round(dwave_annealer_value_most,4))
          row.append(np.round(dwave_annealer_tte,4))

          row_d['solution_first'] = ''.join(map(str, map(int, (dwave_annealer_solution_first))))
          row_d['value_first'] = np.round(dwave_annealer_value_first,4)
          row_d['solution_most'] = ''.join(map(str, map(int, (dwave_annealer_solution_most))))
          row_d['value_most'] = np.round(dwave_annealer_value_most,4)
          row_d['annealer_tte'] = np.round(dwave_annealer_tte,4)

        if gurobipy_qubo_solver:
          if gurobi_qubo_solution:
            row.append(''.join(map(str, map(int, (gurobi_qubo_solution)))))
            row_d['solution_gurobi'] = ''.join(map(str, map(int, (gurobi_qubo_solution))))
          else:
            row.append(''.join(['0']*G.number_of_nodes()))
            row_d['solution_gurobi'] = ''.join(['0']*G.number_of_nodes())
          if gurobi_qubo_value:
            row.append(np.round(gurobi_qubo_value,4))
            row_d['value_gurobi'] = np.round(gurobi_qubo_value,4)
          else:
            row.append(0)
            row_d['value_gurobi'] = 0
          if gurobi_qubo_tte:
            row.append(np.round(gurobi_qubo_tte,4))
            row_d['gurobi_tte'] = np.round(gurobi_qubo_tte,4)
          else:
            row.append(0)
            row_d['gurobi_tte'] = 0

        report_file_obj = open(os.path.join(report_filename),'a+')
        report_file_obj.write('__'.join(map(str,row))+'\n')
        report_file_obj.close()
        table_contents.append(row)

        with open(report_filename_csv, mode='a', newline='') as report_file:
          writer = csv.DictWriter(report_file, fieldnames=row_d.keys())
          writer.writerow(row_d)

        print('\n')
# Out:
# seed: 333, number of agents: 52
# dwave_annealer_tte 5.925198554992676
# dwave_annealer_value_lowest_energy -1159.81
# dwave_annealer_value_most_occurred -1159.81
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 271200.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 95.02, 'qpu_access_time': 287128.76, 'qpu_access_overhead_time': 937.24, 'qpu_programming_time': 15928.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.016908884048461914, 'connection_time': 2.4976861476898193, 'embedding_time': 0.06352496147155762, 'response_time': 0.10477828979492188, 'sample_fetch_time': 0.012887954711914062, 'n': 52, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 53
# dwave_annealer_tte 5.399227857589722
# dwave_annealer_value_lowest_energy -1188.2899999999997
# dwave_annealer_value_most_occurred -1188.2900000000002
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 185360.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 52.1, 'qpu_access_time': 201287.56, 'qpu_access_overhead_time': 1720.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 71.0, 'total_post_processing_time': 71.0, 'problem_formulation_time': 0.005980491638183594, 'connection_time': 2.098740577697754, 'embedding_time': 0.0509645938873291, 'response_time': 0.0837404727935791, 'sample_fetch_time': 0.0, 'n': 53, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 54
# dwave_annealer_tte 5.143293857574463
# dwave_annealer_value_lowest_energy -1197.31
# dwave_annealer_value_most_occurred -1197.31
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 249200.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 84.02, 'qpu_access_time': 264959.96, 'qpu_access_overhead_time': 2638.04, 'qpu_programming_time': 15759.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 293.0, 'total_post_processing_time': 293.0, 'problem_formulation_time': 0.006047487258911133, 'connection_time': 2.043771743774414, 'embedding_time': 0.0646212100982666, 'response_time': 0.10055756568908691, 'sample_fetch_time': 0.0009992122650146484, 'n': 54, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 55
# dwave_annealer_tte 5.326725721359253
# dwave_annealer_value_lowest_energy -1208.92
# dwave_annealer_value_most_occurred -1208.92
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 188760.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 53.8, 'qpu_access_time': 204686.76, 'qpu_access_overhead_time': 1004.24, 'qpu_programming_time': 15926.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 301.0, 'total_post_processing_time': 301.0, 'problem_formulation_time': 0.0061070919036865234, 'connection_time': 2.0452721118927, 'embedding_time': 0.040975332260131836, 'response_time': 0.06562662124633789, 'sample_fetch_time': 0.0010204315185546875, 'n': 55, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 56
# dwave_annealer_tte 5.202102184295654
# dwave_annealer_value_lowest_energy -1208.92
# dwave_annealer_value_most_occurred -1208.9199999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 196600.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 57.72, 'qpu_access_time': 212526.76, 'qpu_access_overhead_time': 1317.24, 'qpu_programming_time': 15926.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 528.0, 'total_post_processing_time': 528.0, 'problem_formulation_time': 0.006000518798828125, 'connection_time': 1.9013514518737793, 'embedding_time': 0.047150611877441406, 'response_time': 0.0686802864074707, 'sample_fetch_time': 0.0009999275207519531, 'n': 56, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 57
# dwave_annealer_tte 5.231044292449951
# dwave_annealer_value_lowest_energy -1208.9199999999998
# dwave_annealer_value_most_occurred -1205.4
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 234560.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 76.7, 'qpu_access_time': 250320.36, 'qpu_access_overhead_time': 1704.64, 'qpu_programming_time': 15760.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.006975650787353516, 'connection_time': 2.159400463104248, 'embedding_time': 0.0439453125, 'response_time': 0.06464314460754395, 'sample_fetch_time': 0.0010006427764892578, 'n': 57, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 58
# dwave_annealer_tte 5.182320594787598
# dwave_annealer_value_lowest_energy -1208.9199999999998
# dwave_annealer_value_most_occurred -1201.92
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 215720.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 67.28, 'qpu_access_time': 231647.56, 'qpu_access_overhead_time': 717.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.0180509090423584, 'connection_time': 1.9153947830200195, 'embedding_time': 0.04888439178466797, 'response_time': 0.06696319580078125, 'sample_fetch_time': 0.0010006427764892578, 'n': 58, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 59
# dwave_annealer_tte 5.206655979156494
# dwave_annealer_value_lowest_energy -1232.14
# dwave_annealer_value_most_occurred -1228.1399999999996
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 345360.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 132.1, 'qpu_access_time': 361119.56, 'qpu_access_overhead_time': 1798.44, 'qpu_programming_time': 15759.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 420.0, 'total_post_processing_time': 420.0, 'problem_formulation_time': 0.005002737045288086, 'connection_time': 1.9915261268615723, 'embedding_time': 0.04507637023925781, 'response_time': 0.06291818618774414, 'sample_fetch_time': 0.0010099411010742188, 'n': 59, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 60
# dwave_annealer_tte 5.428620338439941
# dwave_annealer_value_lowest_energy -1232.1399999999996
# dwave_annealer_value_most_occurred -1232.1399999999999
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 206320.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 62.58, 'qpu_access_time': 222247.96, 'qpu_access_overhead_time': 1446.04, 'qpu_programming_time': 15927.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.021197080612182617, 'connection_time': 2.142307996749878, 'embedding_time': 0.03655886650085449, 'response_time': 0.0627145767211914, 'sample_fetch_time': 0.0010008811950683594, 'n': 60, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 61
# dwave_annealer_tte 5.52008843421936
# dwave_annealer_value_lowest_energy -1232.14
# dwave_annealer_value_most_occurred -1232.14
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 284440.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 101.64, 'qpu_access_time': 300367.16, 'qpu_access_overhead_time': 1061.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 91.0, 'total_post_processing_time': 91.0, 'problem_formulation_time': 0.0060882568359375, 'connection_time': 1.9888429641723633, 'embedding_time': 0.037000417709350586, 'response_time': 0.06559014320373535, 'sample_fetch_time': 0.0009818077087402344, 'n': 61, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 62
# dwave_annealer_tte 5.273469924926758
# dwave_annealer_value_lowest_energy -1232.1399999999999
# dwave_annealer_value_most_occurred -1225.14
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 220040.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 69.44, 'qpu_access_time': 235801.56, 'qpu_access_overhead_time': 1508.44, 'qpu_programming_time': 15761.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 23.0, 'total_post_processing_time': 23.0, 'problem_formulation_time': 0.022507667541503906, 'connection_time': 1.9640097618103027, 'embedding_time': 0.03763866424560547, 'response_time': 0.10161614418029785, 'sample_fetch_time': 0.001020669937133789, 'n': 62, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 63
# dwave_annealer_tte 5.7988810539245605
# dwave_annealer_value_lowest_energy -1232.14
# dwave_annealer_value_most_occurred -1208.86
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 209280.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 64.06, 'qpu_access_time': 225207.16, 'qpu_access_overhead_time': 933.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 285.0, 'total_post_processing_time': 285.0, 'problem_formulation_time': 0.006995439529418945, 'connection_time': 2.38948130607605, 'embedding_time': 0.0487818717956543, 'response_time': 0.06901168823242188, 'sample_fetch_time': 0.0009958744049072266, 'n': 63, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 64
# dwave_annealer_tte 5.275680065155029
# dwave_annealer_value_lowest_energy -1232.1400000000003
# dwave_annealer_value_most_occurred -1232.1399999999999
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 288680.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 103.76, 'qpu_access_time': 304440.36, 'qpu_access_overhead_time': 1785.64, 'qpu_programming_time': 15760.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.006996870040893555, 'connection_time': 2.016864538192749, 'embedding_time': 0.045999765396118164, 'response_time': 0.06751775741577148, 'sample_fetch_time': 0.0, 'n': 64, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 65
# dwave_annealer_tte 5.263850688934326
# dwave_annealer_value_lowest_energy -1232.1400000000006
# dwave_annealer_value_most_occurred -1216.8000000000004
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 230600.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 74.72, 'qpu_access_time': 246527.16, 'qpu_access_overhead_time': 762.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.006017446517944336, 'connection_time': 1.9764809608459473, 'embedding_time': 0.04719662666320801, 'response_time': 0.0690007209777832, 'sample_fetch_time': 0.0010089874267578125, 'n': 65, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 66
# dwave_annealer_tte 5.131302118301392
# dwave_annealer_value_lowest_energy -1232.1399999999999
# dwave_annealer_value_most_occurred -1232.1399999999999
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 183000.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 50.92, 'qpu_access_time': 198927.16, 'qpu_access_overhead_time': 22391.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 58.0, 'total_post_processing_time': 58.0, 'problem_formulation_time': 0.006306171417236328, 'connection_time': 1.8735027313232422, 'embedding_time': 0.04256176948547363, 'response_time': 0.06799125671386719, 'sample_fetch_time': 0.000997304916381836, 'n': 66, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 67
# dwave_annealer_tte 5.969277381896973
# dwave_annealer_value_lowest_energy -1232.1399999999996
# dwave_annealer_value_most_occurred -1228.88
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 290760.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 104.8, 'qpu_access_time': 306687.16, 'qpu_access_overhead_time': 2013.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 437.0, 'total_post_processing_time': 437.0, 'problem_formulation_time': 0.006998538970947266, 'connection_time': 2.423433303833008, 'embedding_time': 0.0397794246673584, 'response_time': 0.06999897956848145, 'sample_fetch_time': 0.0010004043579101562, 'n': 67, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 68
# dwave_annealer_tte 5.339507818222046
# dwave_annealer_value_lowest_energy -1272.94
# dwave_annealer_value_most_occurred -1268.9399999999996
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 187600.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 53.22, 'qpu_access_time': 203360.76, 'qpu_access_overhead_time': 2175.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 88.0, 'total_post_processing_time': 88.0, 'problem_formulation_time': 0.008003473281860352, 'connection_time': 1.9905123710632324, 'embedding_time': 0.04400324821472168, 'response_time': 0.06999373435974121, 'sample_fetch_time': 0.0010027885437011719, 'n': 68, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 69
# dwave_annealer_tte 5.239104747772217
# dwave_annealer_value_lowest_energy -1272.94
# dwave_annealer_value_most_occurred -1269.6799999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 215240.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 67.04, 'qpu_access_time': 231167.56, 'qpu_access_overhead_time': 2819.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.005998134613037109, 'connection_time': 1.9787511825561523, 'embedding_time': 0.05065774917602539, 'response_time': 0.07650208473205566, 'sample_fetch_time': 0.001007080078125, 'n': 69, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 70
# dwave_annealer_tte 5.496833801269531
# dwave_annealer_value_lowest_energy -1269.68
# dwave_annealer_value_most_occurred -1259.1600000000003
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 280680.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 99.76, 'qpu_access_time': 296607.56, 'qpu_access_overhead_time': 1262.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 782.0, 'total_post_processing_time': 782.0, 'problem_formulation_time': 0.005997419357299805, 'connection_time': 1.941631555557251, 'embedding_time': 0.036000967025756836, 'response_time': 0.06954836845397949, 'sample_fetch_time': 0.0, 'n': 70, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 71
# dwave_annealer_tte 5.25054144859314
# dwave_annealer_value_lowest_energy -1328.3300000000004
# dwave_annealer_value_most_occurred -1328.3300000000004
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 234600.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 76.72, 'qpu_access_time': 250360.36, 'qpu_access_overhead_time': 2053.64, 'qpu_programming_time': 15760.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 27.0, 'total_post_processing_time': 27.0, 'problem_formulation_time': 0.005724906921386719, 'connection_time': 1.9656553268432617, 'embedding_time': 0.044513702392578125, 'response_time': 0.08148694038391113, 'sample_fetch_time': 0.0010006427764892578, 'n': 71, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 72
# dwave_annealer_tte 5.887779951095581
# dwave_annealer_value_lowest_energy -1328.3299999999995
# dwave_annealer_value_most_occurred -1315.9099999999994
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 184040.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 51.44, 'qpu_access_time': 199967.56, 'qpu_access_overhead_time': 1746.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 696.0, 'total_post_processing_time': 696.0, 'problem_formulation_time': 0.006055116653442383, 'connection_time': 2.595003604888916, 'embedding_time': 0.04962348937988281, 'response_time': 0.07964134216308594, 'sample_fetch_time': 0.0, 'n': 72, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 73
# dwave_annealer_tte 5.487673282623291
# dwave_annealer_value_lowest_energy -1427.3499999999995
# dwave_annealer_value_most_occurred -1414.9299999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 205520.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 62.18, 'qpu_access_time': 221280.76, 'qpu_access_overhead_time': 2355.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 14.0, 'total_post_processing_time': 14.0, 'problem_formulation_time': 0.007997512817382812, 'connection_time': 1.966198444366455, 'embedding_time': 0.05162692070007324, 'response_time': 0.08150863647460938, 'sample_fetch_time': 0.0009887218475341797, 'n': 73, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 74
# dwave_annealer_tte 5.19023323059082
# dwave_annealer_value_lowest_energy -1427.3500000000001
# dwave_annealer_value_most_occurred -1409.7699999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 197560.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 58.2, 'qpu_access_time': 213486.76, 'qpu_access_overhead_time': 1453.24, 'qpu_programming_time': 15926.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 547.0, 'total_post_processing_time': 547.0, 'problem_formulation_time': 0.007998228073120117, 'connection_time': 1.8681302070617676, 'embedding_time': 0.04149055480957031, 'response_time': 0.07725214958190918, 'sample_fetch_time': 0.00099945068359375, 'n': 74, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 75
# dwave_annealer_tte 5.468242883682251
# dwave_annealer_value_lowest_energy -1476.8499999999997
# dwave_annealer_value_most_occurred -1472.8499999999997
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 287560.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 103.2, 'qpu_access_time': 303487.56, 'qpu_access_overhead_time': 8876.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 54.0, 'total_post_processing_time': 54.0, 'problem_formulation_time': 0.007990837097167969, 'connection_time': 1.9500279426574707, 'embedding_time': 0.05268359184265137, 'response_time': 0.07919955253601074, 'sample_fetch_time': 0.0015158653259277344, 'n': 75, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 76
# dwave_annealer_tte 5.686907768249512
# dwave_annealer_value_lowest_energy -1480.1100000000001
# dwave_annealer_value_most_occurred -1470.9500000000003
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 274720.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 96.78, 'qpu_access_time': 290647.56, 'qpu_access_overhead_time': 1073.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 34.0, 'total_post_processing_time': 34.0, 'problem_formulation_time': 0.007006645202636719, 'connection_time': 2.1478652954101562, 'embedding_time': 0.05152750015258789, 'response_time': 0.08095216751098633, 'sample_fetch_time': 0.0010247230529785156, 'n': 76, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 77
# dwave_annealer_tte 5.3041300773620605
# dwave_annealer_value_lowest_energy -1491.2999999999993
# dwave_annealer_value_most_occurred -1464.7699999999995
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 180920.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 49.88, 'qpu_access_time': 196848.36, 'qpu_access_overhead_time': 1034.64, 'qpu_programming_time': 15928.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 37.0, 'total_post_processing_time': 37.0, 'problem_formulation_time': 0.008055686950683594, 'connection_time': 1.9474782943725586, 'embedding_time': 0.05072188377380371, 'response_time': 0.08131051063537598, 'sample_fetch_time': 0.0010006427764892578, 'n': 77, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 78
# dwave_annealer_tte 6.037273168563843
# dwave_annealer_value_lowest_energy -1507.6799999999998
# dwave_annealer_value_most_occurred -1504.42
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 391280.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 155.06, 'qpu_access_time': 407041.16, 'qpu_access_overhead_time': 1950.84, 'qpu_programming_time': 15761.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 55.0, 'total_post_processing_time': 55.0, 'problem_formulation_time': 0.007993698120117188, 'connection_time': 2.7489700317382812, 'embedding_time': 0.0410008430480957, 'response_time': 0.08051061630249023, 'sample_fetch_time': 0.0010097026824951172, 'n': 78, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 79
# dwave_annealer_tte 5.212629079818726
# dwave_annealer_value_lowest_energy -1519.0300000000002
# dwave_annealer_value_most_occurred -1500.8500000000004
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 342600.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 130.72, 'qpu_access_time': 358361.16, 'qpu_access_overhead_time': 2374.84, 'qpu_programming_time': 15761.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 6.0, 'total_post_processing_time': 6.0, 'problem_formulation_time': 0.007942438125610352, 'connection_time': 1.9470882415771484, 'embedding_time': 0.041605234146118164, 'response_time': 0.07777690887451172, 'sample_fetch_time': 0.0, 'n': 79, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 80
# dwave_annealer_tte 5.240261554718018
# dwave_annealer_value_lowest_energy -1563.37
# dwave_annealer_value_most_occurred -1530.4199999999996
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 219040.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 68.94, 'qpu_access_time': 234967.56, 'qpu_access_overhead_time': 1051.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 697.0, 'total_post_processing_time': 697.0, 'problem_formulation_time': 0.007516384124755859, 'connection_time': 1.9366436004638672, 'embedding_time': 0.0469968318939209, 'response_time': 0.08120441436767578, 'sample_fetch_time': 0.0, 'n': 80, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 81
# dwave_annealer_tte 5.380790948867798
# dwave_annealer_value_lowest_energy -1602.8600000000004
# dwave_annealer_value_most_occurred -1599.6000000000001
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 222480.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 70.66, 'qpu_access_time': 238406.76, 'qpu_access_overhead_time': 1451.24, 'qpu_programming_time': 15926.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.0070650577545166016, 'connection_time': 2.0853614807128906, 'embedding_time': 0.0470423698425293, 'response_time': 0.07978105545043945, 'sample_fetch_time': 0.0010001659393310547, 'n': 81, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 82
# dwave_annealer_tte 5.427133321762085
# dwave_annealer_value_lowest_energy -1602.8600000000001
# dwave_annealer_value_most_occurred -1587.5100000000002
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 205960.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 62.4, 'qpu_access_time': 221886.36, 'qpu_access_overhead_time': 1509.64, 'qpu_programming_time': 15926.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 430.0, 'total_post_processing_time': 430.0, 'problem_formulation_time': 0.009998321533203125, 'connection_time': 2.0885562896728516, 'embedding_time': 0.04285717010498047, 'response_time': 0.07940030097961426, 'sample_fetch_time': 0.0, 'n': 82, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 83
# dwave_annealer_tte 5.338093519210815
# dwave_annealer_value_lowest_energy -1620.96
# dwave_annealer_value_most_occurred -1613.96
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 326800.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 122.82, 'qpu_access_time': 342561.96, 'qpu_access_overhead_time': 2296.04, 'qpu_programming_time': 15761.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 29.0, 'total_post_processing_time': 29.0, 'problem_formulation_time': 0.00799870491027832, 'connection_time': 2.003678798675537, 'embedding_time': 0.05216073989868164, 'response_time': 0.08755970001220703, 'sample_fetch_time': 0.0009996891021728516, 'n': 83, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 84
# dwave_annealer_tte 5.341913223266602
# dwave_annealer_value_lowest_energy -1660.7199999999998
# dwave_annealer_value_most_occurred -1649.7200000000003
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 261960.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 90.4, 'qpu_access_time': 277720.76, 'qpu_access_overhead_time': 1937.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 816.0, 'total_post_processing_time': 816.0, 'problem_formulation_time': 0.007997274398803711, 'connection_time': 2.002552032470703, 'embedding_time': 0.04368424415588379, 'response_time': 0.0841360092163086, 'sample_fetch_time': 0.000997781753540039, 'n': 84, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 85
# dwave_annealer_tte 6.601272106170654
# dwave_annealer_value_lowest_energy -1683.99
# dwave_annealer_value_most_occurred -1659.7799999999995
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 219400.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 69.12, 'qpu_access_time': 235327.16, 'qpu_access_overhead_time': 1308.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 38.0, 'total_post_processing_time': 38.0, 'problem_formulation_time': 0.009000301361083984, 'connection_time': 1.9507412910461426, 'embedding_time': 1.1885137557983398, 'response_time': 0.09016895294189453, 'sample_fetch_time': 0.0015070438385009766, 'n': 85, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 86
# dwave_annealer_tte 6.830366373062134
# dwave_annealer_value_lowest_energy -1721.1100000000001
# dwave_annealer_value_most_occurred -1716.7700000000004
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 227040.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 72.94, 'qpu_access_time': 242967.16, 'qpu_access_overhead_time': 5419.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 47.0, 'total_post_processing_time': 47.0, 'problem_formulation_time': 0.0238034725189209, 'connection_time': 3.009974241256714, 'embedding_time': 0.10933542251586914, 'response_time': 0.19955992698669434, 'sample_fetch_time': 0.0019843578338623047, 'n': 86, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 87
# dwave_annealer_tte 6.063298940658569
# dwave_annealer_value_lowest_energy -1729.4500000000003
# dwave_annealer_value_most_occurred -1717.1100000000001
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 247640.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 83.24, 'qpu_access_time': 263399.96, 'qpu_access_overhead_time': 2119.04, 'qpu_programming_time': 15759.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.028657197952270508, 'connection_time': 2.36897349357605, 'embedding_time': 0.12254762649536133, 'response_time': 0.21144556999206543, 'sample_fetch_time': 0.0020003318786621094, 'n': 87, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 88
# dwave_annealer_tte 6.845919370651245
# dwave_annealer_value_lowest_energy -1729.4500000000003
# dwave_annealer_value_most_occurred -1711.9500000000003
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 344920.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 131.88, 'qpu_access_time': 360680.76, 'qpu_access_overhead_time': 3434.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.026999950408935547, 'connection_time': 2.2374861240386963, 'embedding_time': 0.12108421325683594, 'response_time': 0.21706342697143555, 'sample_fetch_time': 0.001999378204345703, 'n': 88, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 89
# dwave_annealer_tte 6.036682844161987
# dwave_annealer_value_lowest_energy -1725.93
# dwave_annealer_value_most_occurred -1705.8400000000001
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 177400.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 48.12, 'qpu_access_time': 193327.96, 'qpu_access_overhead_time': 1117.04, 'qpu_programming_time': 15927.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 565.0, 'total_post_processing_time': 565.0, 'problem_formulation_time': 0.027036190032958984, 'connection_time': 2.3172812461853027, 'embedding_time': 0.125504732131958, 'response_time': 0.21489334106445312, 'sample_fetch_time': 0.0020189285278320312, 'n': 89, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 90
# dwave_annealer_tte 5.972477912902832
# dwave_annealer_value_lowest_energy -1729.4500000000003
# dwave_annealer_value_most_occurred -1699.0800000000004
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 266160.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 92.5, 'qpu_access_time': 281920.76, 'qpu_access_overhead_time': 1833.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 453.0, 'total_post_processing_time': 453.0, 'problem_formulation_time': 0.03097701072692871, 'connection_time': 2.247770071029663, 'embedding_time': 0.09659314155578613, 'response_time': 0.21698307991027832, 'sample_fetch_time': 0.0020029544830322266, 'n': 90, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 91
# dwave_annealer_tte 6.086855888366699
# dwave_annealer_value_lowest_energy -1771.4900000000002
# dwave_annealer_value_most_occurred -1766.5499999999997
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 210040.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 64.44, 'qpu_access_time': 225967.56, 'qpu_access_overhead_time': 99155.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 838.0, 'total_post_processing_time': 838.0, 'problem_formulation_time': 0.02458024024963379, 'connection_time': 2.223472833633423, 'embedding_time': 0.0955665111541748, 'response_time': 0.370328426361084, 'sample_fetch_time': 0.0010035037994384766, 'n': 91, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 92
# dwave_annealer_tte 6.358942985534668
# dwave_annealer_value_lowest_energy -1779.2300000000002
# dwave_annealer_value_most_occurred -1735.7400000000002
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 268200.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 93.52, 'qpu_access_time': 284127.56, 'qpu_access_overhead_time': 1426.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 95.0, 'total_post_processing_time': 95.0, 'problem_formulation_time': 0.03200531005859375, 'connection_time': 2.184056043624878, 'embedding_time': 0.10256290435791016, 'response_time': 0.22018027305603027, 'sample_fetch_time': 0.002015352249145508, 'n': 92, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 93
# dwave_annealer_tte 6.028611660003662
# dwave_annealer_value_lowest_energy -1826.78
# dwave_annealer_value_most_occurred -1826.78
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 212840.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 65.84, 'qpu_access_time': 228765.96, 'qpu_access_overhead_time': 1681.04, 'qpu_programming_time': 15925.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 183.0, 'total_post_processing_time': 183.0, 'problem_formulation_time': 0.0725247859954834, 'connection_time': 2.2456376552581787, 'embedding_time': 0.11859893798828125, 'response_time': 0.23158049583435059, 'sample_fetch_time': 0.002005338668823242, 'n': 93, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 94
# dwave_annealer_tte 9.142525434494019
# dwave_annealer_value_lowest_energy -1842.6400000000003
# dwave_annealer_value_most_occurred -1835.8600000000006
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 194000.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 56.42, 'qpu_access_time': 209760.76, 'qpu_access_overhead_time': 2390.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 29.0, 'total_post_processing_time': 29.0, 'problem_formulation_time': 0.034011125564575195, 'connection_time': 5.34343957901001, 'embedding_time': 0.09559965133666992, 'response_time': 0.21926236152648926, 'sample_fetch_time': 0.0020020008087158203, 'n': 94, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 95
# dwave_annealer_tte 5.7937586307525635
# dwave_annealer_value_lowest_energy -1834.0900000000004
# dwave_annealer_value_most_occurred -1834.0900000000004
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 224080.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 71.46, 'qpu_access_time': 240007.16, 'qpu_access_overhead_time': 1583.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 55.0, 'total_post_processing_time': 55.0, 'problem_formulation_time': 0.029035329818725586, 'connection_time': 2.0795915126800537, 'embedding_time': 0.10081887245178223, 'response_time': 0.2275097370147705, 'sample_fetch_time': 0.0020008087158203125, 'n': 95, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 96
# dwave_annealer_tte 6.0557262897491455
# dwave_annealer_value_lowest_energy -1842.6899999999998
# dwave_annealer_value_most_occurred -1830.83
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 234920.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 76.88, 'qpu_access_time': 250679.96, 'qpu_access_overhead_time': 1936.04, 'qpu_programming_time': 15759.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.03899741172790527, 'connection_time': 2.1918063163757324, 'embedding_time': 0.10955286026000977, 'response_time': 0.3770768642425537, 'sample_fetch_time': 0.002005338668823242, 'n': 96, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 97
# dwave_annealer_tte 6.035778760910034
# dwave_annealer_value_lowest_energy -1834.0900000000006
# dwave_annealer_value_most_occurred -1807.1499999999996
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 230960.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 74.9, 'qpu_access_time': 246886.36, 'qpu_access_overhead_time': 1276.64, 'qpu_programming_time': 15926.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.035094261169433594, 'connection_time': 2.234738826751709, 'embedding_time': 0.10174942016601562, 'response_time': 0.2310190200805664, 'sample_fetch_time': 0.0020036697387695312, 'n': 97, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 98
# dwave_annealer_tte 5.9179487228393555
# dwave_annealer_value_lowest_energy -1842.6400000000003
# dwave_annealer_value_most_occurred -1842.6400000000003
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 271440.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 95.14, 'qpu_access_time': 287200.76, 'qpu_access_overhead_time': 1966.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 20.0, 'total_post_processing_time': 20.0, 'problem_formulation_time': 0.028901100158691406, 'connection_time': 2.1692159175872803, 'embedding_time': 0.10459113121032715, 'response_time': 0.2301650047302246, 'sample_fetch_time': 0.001973867416381836, 'n': 98, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 99
# dwave_annealer_tte 5.995882987976074
# dwave_annealer_value_lowest_energy -1892.4700000000007
# dwave_annealer_value_most_occurred -1892.4700000000007
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 194840.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 56.84, 'qpu_access_time': 210767.56, 'qpu_access_overhead_time': 1778.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 757.0, 'total_post_processing_time': 757.0, 'problem_formulation_time': 0.03921198844909668, 'connection_time': 2.2301952838897705, 'embedding_time': 0.10596537590026855, 'response_time': 0.24212360382080078, 'sample_fetch_time': 0.0020177364349365234, 'n': 99, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 100
# dwave_annealer_tte 6.022810935974121
# dwave_annealer_value_lowest_energy -1967.3000000000006
# dwave_annealer_value_most_occurred -1967.3000000000006
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 313720.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 116.28, 'qpu_access_time': 329480.36, 'qpu_access_overhead_time': 2546.64, 'qpu_programming_time': 15760.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.03558707237243652, 'connection_time': 2.2184531688690186, 'embedding_time': 0.10144186019897461, 'response_time': 0.23858118057250977, 'sample_fetch_time': 0.0019998550415039062, 'n': 100, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 101
# dwave_annealer_tte 6.1243367195129395
# dwave_annealer_value_lowest_energy -2035.7500000000002
# dwave_annealer_value_most_occurred -1981.9300000000003
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 253960.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 86.4, 'qpu_access_time': 269887.56, 'qpu_access_overhead_time': 1427.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.04199719429016113, 'connection_time': 2.2149548530578613, 'embedding_time': 0.10254573822021484, 'response_time': 0.2436046600341797, 'sample_fetch_time': 0.0009965896606445312, 'n': 101, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 102
# dwave_annealer_tte 6.214621543884277
# dwave_annealer_value_lowest_energy -2122.27
# dwave_annealer_value_most_occurred -2108.47
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 264280.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 91.56, 'qpu_access_time': 280040.76, 'qpu_access_overhead_time': 2363.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 135.0, 'total_post_processing_time': 135.0, 'problem_formulation_time': 0.08410954475402832, 'connection_time': 2.374870777130127, 'embedding_time': 0.10371804237365723, 'response_time': 0.2460346221923828, 'sample_fetch_time': 0.0019960403442382812, 'n': 102, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 103
# dwave_annealer_tte 5.931839466094971
# dwave_annealer_value_lowest_energy -2120.35
# dwave_annealer_value_most_occurred -2116.18
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 222920.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 70.88, 'qpu_access_time': 238847.56, 'qpu_access_overhead_time': 1845.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 930.0, 'total_post_processing_time': 930.0, 'problem_formulation_time': 0.039685726165771484, 'connection_time': 2.1507654190063477, 'embedding_time': 0.1032724380493164, 'response_time': 0.25879955291748047, 'sample_fetch_time': 0.0019969940185546875, 'n': 103, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 104
# dwave_annealer_tte 5.953716993331909
# dwave_annealer_value_lowest_energy -2202.21
# dwave_annealer_value_most_occurred -2202.21
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 189680.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 54.26, 'qpu_access_time': 205607.16, 'qpu_access_overhead_time': 1094.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 56.0, 'total_post_processing_time': 56.0, 'problem_formulation_time': 0.035947322845458984, 'connection_time': 2.1325087547302246, 'embedding_time': 0.10683131217956543, 'response_time': 0.24338030815124512, 'sample_fetch_time': 0.0020003318786621094, 'n': 104, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 105
# dwave_annealer_tte 9.720130205154419
# dwave_annealer_value_lowest_energy -2208.48
# dwave_annealer_value_most_occurred -2207.4499999999994
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 215760.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 67.3, 'qpu_access_time': 231687.96, 'qpu_access_overhead_time': 12755.04, 'qpu_programming_time': 15927.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 18.0, 'total_post_processing_time': 18.0, 'problem_formulation_time': 0.031832218170166016, 'connection_time': 5.918144226074219, 'embedding_time': 0.10381340980529785, 'response_time': 0.2570514678955078, 'sample_fetch_time': 0.001001596450805664, 'n': 105, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 106
# dwave_annealer_tte 6.064432144165039
# dwave_annealer_value_lowest_energy -2212.27
# dwave_annealer_value_most_occurred -2212.27
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 252200.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 85.52, 'qpu_access_time': 267960.76, 'qpu_access_overhead_time': 3166.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 149.0, 'total_post_processing_time': 149.0, 'problem_formulation_time': 0.042853593826293945, 'connection_time': 2.214566469192505, 'embedding_time': 0.1056828498840332, 'response_time': 0.26289868354797363, 'sample_fetch_time': 0.0020008087158203125, 'n': 106, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 107
# dwave_annealer_tte 6.083498239517212
# dwave_annealer_value_lowest_energy -2278.63
# dwave_annealer_value_most_occurred -2225.4400000000005
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 231120.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 74.98, 'qpu_access_time': 247045.96, 'qpu_access_overhead_time': 2052.04, 'qpu_programming_time': 15925.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 15.0, 'total_post_processing_time': 15.0, 'problem_formulation_time': 0.037984609603881836, 'connection_time': 2.242846965789795, 'embedding_time': 0.10483288764953613, 'response_time': 0.25344038009643555, 'sample_fetch_time': 0.002088308334350586, 'n': 107, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 108
# dwave_annealer_tte 6.048980951309204
# dwave_annealer_value_lowest_energy -2275.8000000000006
# dwave_annealer_value_most_occurred -2275.8000000000006
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 329440.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 124.14, 'qpu_access_time': 345199.56, 'qpu_access_overhead_time': 3052.44, 'qpu_programming_time': 15759.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 30.0, 'total_post_processing_time': 30.0, 'problem_formulation_time': 0.032825469970703125, 'connection_time': 2.214749813079834, 'embedding_time': 0.10491561889648438, 'response_time': 0.2573280334472656, 'sample_fetch_time': 0.0009953975677490234, 'n': 108, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 109
# dwave_annealer_tte 5.973604202270508
# dwave_annealer_value_lowest_energy -2279.3199999999997
# dwave_annealer_value_most_occurred -2279.3199999999997
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 230240.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 74.54, 'qpu_access_time': 246167.56, 'qpu_access_overhead_time': 1777.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.03300046920776367, 'connection_time': 2.1643824577331543, 'embedding_time': 0.11152935028076172, 'response_time': 0.26600146293640137, 'sample_fetch_time': 0.0020837783813476562, 'n': 109, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 110
# dwave_annealer_tte 6.318392753601074
# dwave_annealer_value_lowest_energy -2305.15
# dwave_annealer_value_most_occurred -2305.15
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 289000.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 103.92, 'qpu_access_time': 304925.96, 'qpu_access_overhead_time': 1643.04, 'qpu_programming_time': 15925.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 27.0, 'total_post_processing_time': 27.0, 'problem_formulation_time': 0.0419924259185791, 'connection_time': 2.246281147003174, 'embedding_time': 0.10700488090515137, 'response_time': 0.2672555446624756, 'sample_fetch_time': 0.002006053924560547, 'n': 110, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 111
# dwave_annealer_tte 6.0312180519104
# dwave_annealer_value_lowest_energy -2405.97
# dwave_annealer_value_most_occurred -2361.0899999999997
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 310320.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 114.58, 'qpu_access_time': 326080.76, 'qpu_access_overhead_time': 2615.24, 'qpu_programming_time': 15760.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.04497861862182617, 'connection_time': 2.218902587890625, 'embedding_time': 0.10681796073913574, 'response_time': 0.26915645599365234, 'sample_fetch_time': 0.002065420150756836, 'n': 111, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 112
# dwave_annealer_tte 6.430319547653198
# dwave_annealer_value_lowest_energy -2395.01
# dwave_annealer_value_most_occurred -2395.01
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 293040.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 105.94, 'qpu_access_time': 308965.56, 'qpu_access_overhead_time': 1564.44, 'qpu_programming_time': 15925.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 418.0, 'total_post_processing_time': 418.0, 'problem_formulation_time': 0.04503178596496582, 'connection_time': 2.2641327381134033, 'embedding_time': 0.1168673038482666, 'response_time': 0.2755911350250244, 'sample_fetch_time': 0.0010082721710205078, 'n': 112, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 113
# dwave_annealer_tte 6.266259670257568
# dwave_annealer_value_lowest_energy -2488.34
# dwave_annealer_value_most_occurred -2488.34
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 289480.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 104.16, 'qpu_access_time': 305406.76, 'qpu_access_overhead_time': 1060.24, 'qpu_programming_time': 15926.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 47.0, 'total_post_processing_time': 47.0, 'problem_formulation_time': 0.03998231887817383, 'connection_time': 2.186157703399658, 'embedding_time': 0.1065514087677002, 'response_time': 0.2658722400665283, 'sample_fetch_time': 0.0009930133819580078, 'n': 113, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 114
# dwave_annealer_tte 5.952148914337158
# dwave_annealer_value_lowest_energy -2512.28
# dwave_annealer_value_most_occurred -2474.2100000000005
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 407720.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 163.28, 'qpu_access_time': 423481.16, 'qpu_access_overhead_time': 2523.84, 'qpu_programming_time': 15761.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 37.0, 'total_post_processing_time': 37.0, 'problem_formulation_time': 0.03500175476074219, 'connection_time': 2.1511802673339844, 'embedding_time': 0.10882329940795898, 'response_time': 0.2669343948364258, 'sample_fetch_time': 0.002021312713623047, 'n': 114, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 115
# dwave_annealer_tte 6.2707908153533936
# dwave_annealer_value_lowest_energy -2585.0599999999995
# dwave_annealer_value_most_occurred -2526.2299999999996
# ANNEALER DONE!
# ...
#
#
# seed: 333, number of agents: 471
# dwave_annealer_tte 12.946589946746826
# dwave_annealer_value_lowest_energy -10760.719999999992
# dwave_annealer_value_most_occurred -10760.719999999992
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 319000.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 118.92, 'qpu_access_time': 334927.56, 'qpu_access_overhead_time': 2343.44, 'qpu_programming_time': 15927.56, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 72.0, 'total_post_processing_time': 72.0, 'problem_formulation_time': 0.10783052444458008, 'connection_time': 3.2950191497802734, 'embedding_time': 0.35844898223876953, 'response_time': 4.884553670883179, 'sample_fetch_time': 0.0010006427764892578, 'n': 471, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 472
# dwave_annealer_tte 11.5962553024292
# dwave_annealer_value_lowest_energy -10801.899999999998
# dwave_annealer_value_most_occurred -10801.899999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 308160.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 113.5, 'qpu_access_time': 324087.16, 'qpu_access_overhead_time': 2920.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 433.0, 'total_post_processing_time': 433.0, 'problem_formulation_time': 0.10671806335449219, 'connection_time': 3.198441982269287, 'embedding_time': 0.3744015693664551, 'response_time': 3.6763787269592285, 'sample_fetch_time': 0.0, 'n': 472, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 473
# dwave_annealer_tte 23.971594095230103
# dwave_annealer_value_lowest_energy -10823.150000000003
# dwave_annealer_value_most_occurred -10823.150000000003
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 443120.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 180.98, 'qpu_access_time': 458884.76, 'qpu_access_overhead_time': 4479.24, 'qpu_programming_time': 15764.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 42.0, 'total_post_processing_time': 42.0, 'problem_formulation_time': 0.12955498695373535, 'connection_time': 3.30326247215271, 'embedding_time': 0.3947896957397461, 'response_time': 16.13576650619507, 'sample_fetch_time': 0.0009992122650146484, 'n': 473, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 474
# dwave_annealer_tte 18.61512804031372
# dwave_annealer_value_lowest_energy -10807.3
# dwave_annealer_value_most_occurred -10807.3
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 344840.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 131.84, 'qpu_access_time': 360767.16, 'qpu_access_overhead_time': 2560.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 44.0, 'total_post_processing_time': 44.0, 'problem_formulation_time': 0.10174393653869629, 'connection_time': 3.785642147064209, 'embedding_time': 0.3699610233306885, 'response_time': 9.87492823600769, 'sample_fetch_time': 0.001001596450805664, 'n': 474, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 475
# dwave_annealer_tte 23.118088483810425
# dwave_annealer_value_lowest_energy -10925.760000000013
# dwave_annealer_value_most_occurred -10925.760000000013
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 348800.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 133.82, 'qpu_access_time': 364564.76, 'qpu_access_overhead_time': 6048.24, 'qpu_programming_time': 15764.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 23.0, 'total_post_processing_time': 23.0, 'problem_formulation_time': 0.10967516899108887, 'connection_time': 3.7129180431365967, 'embedding_time': 0.4017019271850586, 'response_time': 14.906153917312622, 'sample_fetch_time': 0.0009980201721191406, 'n': 475, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 476
# dwave_annealer_tte 26.88933038711548
# dwave_annealer_value_lowest_energy -10955.32000000001
# dwave_annealer_value_most_occurred -10955.32000000001
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 383520.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 151.18, 'qpu_access_time': 399286.76, 'qpu_access_overhead_time': 6057.24, 'qpu_programming_time': 15766.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.10994291305541992, 'connection_time': 3.9426088333129883, 'embedding_time': 0.3960893154144287, 'response_time': 18.0589120388031, 'sample_fetch_time': 0.0010004043579101562, 'n': 476, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 477
# dwave_annealer_tte 52.45799136161804
# dwave_annealer_value_lowest_energy -10970.889999999992
# dwave_annealer_value_most_occurred -10970.889999999992
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 218440.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 68.64, 'qpu_access_time': 234367.16, 'qpu_access_overhead_time': 2129.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 843.0, 'total_post_processing_time': 843.0, 'problem_formulation_time': 0.1449596881866455, 'connection_time': 5.690489768981934, 'embedding_time': 0.5762672424316406, 'response_time': 41.694583892822266, 'sample_fetch_time': 0.0010020732879638672, 'n': 477, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 478
# dwave_annealer_tte 23.447247982025146
# dwave_annealer_value_lowest_energy -11125.840000000006
# dwave_annealer_value_most_occurred -11125.840000000006
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 410360.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 164.6, 'qpu_access_time': 426127.16, 'qpu_access_overhead_time': 6133.84, 'qpu_programming_time': 15767.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 120.0, 'total_post_processing_time': 120.0, 'problem_formulation_time': 0.1392228603363037, 'connection_time': 5.46914005279541, 'embedding_time': 0.36165952682495117, 'response_time': 13.0171799659729, 'sample_fetch_time': 0.001027822494506836, 'n': 478, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 479
# dwave_annealer_tte 17.222352504730225
# dwave_annealer_value_lowest_energy -11056.780000000004
# dwave_annealer_value_most_occurred -11056.780000000004
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 248680.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 83.76, 'qpu_access_time': 264604.76, 'qpu_access_overhead_time': 2361.24, 'qpu_programming_time': 15924.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 820.0, 'total_post_processing_time': 820.0, 'problem_formulation_time': 0.13602161407470703, 'connection_time': 5.6060426235198975, 'embedding_time': 0.4165160655975342, 'response_time': 6.785980463027954, 'sample_fetch_time': 0.0009992122650146484, 'n': 479, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 480
# dwave_annealer_tte 42.072418212890625
# dwave_annealer_value_lowest_energy -11167.890000000001
# dwave_annealer_value_most_occurred -11167.890000000001
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 308000.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 113.42, 'qpu_access_time': 323764.36, 'qpu_access_overhead_time': 6107.64, 'qpu_programming_time': 15764.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.11568260192871094, 'connection_time': 5.460300445556641, 'embedding_time': 0.391033411026001, 'response_time': 32.10214900970459, 'sample_fetch_time': 0.0010006427764892578, 'n': 480, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 481
# dwave_annealer_tte 47.950652837753296
# dwave_annealer_value_lowest_energy -11136.149999999992
# dwave_annealer_value_most_occurred -11136.149999999992
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 258360.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 88.6, 'qpu_access_time': 274289.16, 'qpu_access_overhead_time': 1883.84, 'qpu_programming_time': 15929.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 7.0, 'total_post_processing_time': 7.0, 'problem_formulation_time': 0.12451052665710449, 'connection_time': 3.3417177200317383, 'embedding_time': 0.3603026866912842, 'response_time': 40.18723654747009, 'sample_fetch_time': 0.0010008811950683594, 'n': 481, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 482
# dwave_annealer_tte 19.960638523101807
# dwave_annealer_value_lowest_energy -11222.069999999998
# dwave_annealer_value_most_occurred -11222.069999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 243400.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 81.12, 'qpu_access_time': 259165.96, 'qpu_access_overhead_time': 5043.04, 'qpu_programming_time': 15765.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.11468338966369629, 'connection_time': 3.295823097229004, 'embedding_time': 0.36167430877685547, 'response_time': 12.231911659240723, 'sample_fetch_time': 0.0011138916015625, 'n': 482, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 483
# dwave_annealer_tte 32.34257698059082
# dwave_annealer_value_lowest_energy -11167.589999999993
# dwave_annealer_value_most_occurred -11167.589999999993
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 362560.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 140.7, 'qpu_access_time': 378485.16, 'qpu_access_overhead_time': 3106.84, 'qpu_programming_time': 15925.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 363.0, 'total_post_processing_time': 363.0, 'problem_formulation_time': 0.11109304428100586, 'connection_time': 3.6762187480926514, 'embedding_time': 0.408064603805542, 'response_time': 23.664477586746216, 'sample_fetch_time': 0.0010008811950683594, 'n': 483, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 484
# dwave_annealer_tte 29.24514889717102
# dwave_annealer_value_lowest_energy -11252.329999999998
# dwave_annealer_value_most_occurred -11252.329999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 342840.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 130.84, 'qpu_access_time': 358605.96, 'qpu_access_overhead_time': 4713.04, 'qpu_programming_time': 15765.96, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 30.0, 'total_post_processing_time': 30.0, 'problem_formulation_time': 0.13854074478149414, 'connection_time': 3.749596118927002, 'embedding_time': 0.36260223388671875, 'response_time': 21.0310115814209, 'sample_fetch_time': 0.000997781753540039, 'n': 484, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 485
# dwave_annealer_tte 21.906455039978027
# dwave_annealer_value_lowest_energy -11356.729999999998
# dwave_annealer_value_most_occurred -11356.729999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 361880.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 140.36, 'qpu_access_time': 377807.16, 'qpu_access_overhead_time': 2870.84, 'qpu_programming_time': 15927.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.1399824619293213, 'connection_time': 3.228924512863159, 'embedding_time': 0.3778533935546875, 'response_time': 13.683574199676514, 'sample_fetch_time': 0.0010013580322265625, 'n': 485, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 486
# dwave_annealer_tte 18.853712797164917
# dwave_annealer_value_lowest_energy -11314.110000000006
# dwave_annealer_value_most_occurred -11314.110000000006
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 397800.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 158.32, 'qpu_access_time': 413566.36, 'qpu_access_overhead_time': 8374.64, 'qpu_programming_time': 15766.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 70.0, 'total_post_processing_time': 70.0, 'problem_formulation_time': 0.11394047737121582, 'connection_time': 3.2781858444213867, 'embedding_time': 0.3598461151123047, 'response_time': 11.051839113235474, 'sample_fetch_time': 0.0009953975677490234, 'n': 486, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 487
# dwave_annealer_tte 18.14834237098694
# dwave_annealer_value_lowest_energy -11421.859999999997
# dwave_annealer_value_most_occurred -11421.859999999997
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 407880.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 163.36, 'qpu_access_time': 423647.16, 'qpu_access_overhead_time': 5830.84, 'qpu_programming_time': 15767.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 1.0, 'total_post_processing_time': 1.0, 'problem_formulation_time': 0.11002826690673828, 'connection_time': 3.2748401165008545, 'embedding_time': 0.38307738304138184, 'response_time': 9.979160785675049, 'sample_fetch_time': 0.0010004043579101562, 'n': 487, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 488
# dwave_annealer_tte 18.161051034927368
# dwave_annealer_value_lowest_energy -11368.389999999992
# dwave_annealer_value_most_occurred -11368.389999999992
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 278680.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 98.76, 'qpu_access_time': 294606.76, 'qpu_access_overhead_time': 2620.24, 'qpu_programming_time': 15926.76, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 11.0, 'total_post_processing_time': 11.0, 'problem_formulation_time': 0.11050581932067871, 'connection_time': 5.370285987854004, 'embedding_time': 0.3744933605194092, 'response_time': 7.885639190673828, 'sample_fetch_time': 0.001001119613647461, 'n': 488, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 489
# dwave_annealer_tte 21.047106504440308
# dwave_annealer_value_lowest_energy -11396.480000000009
# dwave_annealer_value_most_occurred -11396.480000000009
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 316360.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 117.6, 'qpu_access_time': 332125.16, 'qpu_access_overhead_time': 6009.84, 'qpu_programming_time': 15765.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 46.0, 'total_post_processing_time': 46.0, 'problem_formulation_time': 0.12082195281982422, 'connection_time': 5.439570903778076, 'embedding_time': 0.39046406745910645, 'response_time': 10.694687843322754, 'sample_fetch_time': 0.0009999275207519531, 'n': 489, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 490
# dwave_annealer_tte 15.830859661102295
# dwave_annealer_value_lowest_energy -11330.669999999998
# dwave_annealer_value_most_occurred -11330.669999999998
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 289400.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 104.12, 'qpu_access_time': 305326.36, 'qpu_access_overhead_time': 2450.64, 'qpu_programming_time': 15926.36, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 433.0, 'total_post_processing_time': 433.0, 'problem_formulation_time': 0.14384937286376953, 'connection_time': 5.264674425125122, 'embedding_time': 0.3728981018066406, 'response_time': 5.3919782638549805, 'sample_fetch_time': 0.0010099411010742188, 'n': 490, 'sparsity': 1.0}
#
#
# seed: 333, number of agents: 491
# dwave_annealer_tte 19.71789813041687
# dwave_annealer_value_lowest_energy -11351.900000000005
# dwave_annealer_value_most_occurred -11351.900000000005
# ANNEALER DONE!
# qputime_dic {'qpu_sampling_time': 406560.0, 'qpu_anneal_time_per_sample': 20.0, 'qpu_readout_time_per_sample': 162.7, 'qpu_access_time': 422327.16, 'qpu_access_overhead_time': 5522.84, 'qpu_programming_time': 15767.16, 'qpu_delay_time_per_sample': 20.58, 'post_processing_overhead_time': 25.0, 'total_post_processing_time': 25.0, 'problem_formulation_time': 0.1285548210144043, 'connection_time': 5.361908435821533, 'embedding_time': 0.3885459899902344, 'response_time': 9.813891410827637, 'sample_fetch_time': 0.001008749008178711, 'n': 491, 'sparsity': 1.0}

# %% [markdown]
# ### Gurobi Experiments

# %% [markdown]
# #### Experimental settings

# %%
# seeds = [111,222,333]

seed = 333

dwave_annealer_solver = False#@param {type:"boolean"}
gurobipy_qubo_solver = True#@param {type:"boolean"}

solver_flags = ''.join(map(str,map(int,[dwave_annealer_solver, gurobipy_qubo_solver])))


table_contents = []

report_filename = 'optimalSplit_report_' + solver_flags + '_' +  str(seed) + '.txt'
report_filename_csv = 'optimalSplit_report_' + solver_flags + '_' +  str(seed) + '.csv'
qputimes_filename = 'optimalSplit_qputimes_' + solver_flags + '_' +  str(seed) + '.csv'

qpu_output_path = os.path.join('singleSplitresults', f'{seed}')

n_samples = 2000

# %%
# Create the directory if it doesn't exist

fieldnames = ['n', 'sparsity', 'distribution', 'seed', 'solution_gurobi', 'value_gurobi', 'gurobi_tte']
if not os.path.exists(report_filename_csv):
  with open(report_filename_csv, mode='w', newline='') as report_file:
        writer = csv.DictWriter(report_file, fieldnames=fieldnames)
        # Write the header row
        writer.writeheader()

# %%
distributions = [
    utils.random
]

sparsities = [0.0,0.5,1.0]

seeds = [111,222,333]

n_agents = np.arange(2,521)

# %% [markdown]
# #### Executions

# %%
for seed in seeds:
  for distribution in distributions:
    for n in n_agents:
      for sparsity in sparsities:
        base_path = os.path.join(qpu_output_path, str(seed),f"sparsity{sparsity}")
        os.makedirs(base_path, exist_ok=True)
        print(f'seed: {seed}, number of agents: {n}')
        np.random.seed(seed=seed)
        isg, G = generate_induced_subgraph_game(distribution, n, sparsity=sparsity, seed = seed)
        start_time = time.time()
        if dwave_annealer_solver:
          sample_set_df, info_dict = annealer_solver(G, private_token='xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx', n_samples = n_samples)
          dwave_annealer_tte = (time.time() - start_time)
          print('dwave_annealer_tte',dwave_annealer_tte)
          dwave_annealer_solution_first = ''.join(sample_set_df.iloc[0][:-3].astype(int).astype(str))
          dwave_annealer_solution_most = ''.join(sample_set_df.sort_values(by=['num_occurrences', 'energy'], ascending=[False, True]).iloc[0][:-3].astype(int).astype(str))

          dwave_annealer_value_first = sample_set_df.iloc[0][-2:-1][0]
          dwave_annealer_value_most = sample_set_df.sort_values(by=['num_occurrences', 'energy'], ascending=[False, True]).iloc[0][-2:-1][0]

          print('dwave_annealer_value_lowest_energy',dwave_annealer_value_first)
          print('dwave_annealer_value_most_occurred',dwave_annealer_value_most)

          print("ANNEALER DONE!")
          qputime_dic = info_dict.copy()
          qputime_dic['n'] = n
          qputime_dic['sparsity'] = sparsity
          print('qputime_dic',qputime_dic)
  
          sample_set_df.to_csv(os.path.join(base_path, f'{n}.csv'), index=False)

          with open(qputimes_filename, mode='a', newline='') as qpu_times_file:
            writer = csv.DictWriter(qpu_times_file, fieldnames=qputime_dic.keys())
            writer.writerow(qputime_dic)
        else:
          dwave_annealer_solution, dwave_annealer_value = None, None
  
  
        start_time = time.time()
        if gurobipy_qubo_solver:
          try:
            gurobi_qubo_solution, gurobi_qubo_value = gurobi_qubo_solver(G)
            gurobi_qubo_tte = (time.time() - start_time)
            print('gurobi_qubo_value',gurobi_qubo_value)
            print('gurobi_qubo_tte:',gurobi_qubo_tte)
            print("GUROBI QUBO DONE!")
          except Exception as e:
            print("Gurobi QUBO execution is unsuccessful due to "+ str(e))
            gurobi_qubo_solution, gurobi_qubo_value = None, None
        else:
          gurobi_qubo_solution, gurobi_qubo_value = None, None

        row = []
        row_d = {}

        row.append(int(n))
        row.append(np.round(sparsity,4))
        row.append(distribution.__name__)
        row.append(seed)


        row_d['n'] = int(n)
        row_d['sparsity'] = np.round(sparsity,4)
        row_d['distribution'] = distribution.__name__
        row_d['seed'] = seed
        # row.append(int(width))

        if dwave_annealer_solver:
          row.append(''.join(map(str, map(int, (dwave_annealer_solution_first)))))
          row.append(np.round(dwave_annealer_value_first,4))
          row.append(''.join(map(str, map(int, (dwave_annealer_solution_most)))))
          row.append(np.round(dwave_annealer_value_most,4))
          row.append(np.round(dwave_annealer_tte,4))

          row_d['solution_first'] = ''.join(map(str, map(int, (dwave_annealer_solution_first))))
          row_d['value_first'] = np.round(dwave_annealer_value_first,4)
          row_d['solution_most'] = ''.join(map(str, map(int, (dwave_annealer_solution_most))))
          row_d['value_most'] = np.round(dwave_annealer_value_most,4)
          row_d['annealer_tte'] = np.round(dwave_annealer_tte,4)

        if gurobipy_qubo_solver:
          if gurobi_qubo_solution:
            row.append(''.join(map(str, map(int, (gurobi_qubo_solution)))))
            row_d['solution_gurobi'] = ''.join(map(str, map(int, (gurobi_qubo_solution))))
          else:
            row.append(''.join(['0']*G.number_of_nodes()))
            row_d['solution_gurobi'] = ''.join(['0']*G.number_of_nodes())
          if gurobi_qubo_value:
            row.append(np.round(gurobi_qubo_value,4))
            row_d['value_gurobi'] = np.round(gurobi_qubo_value,4)
          else:
            row.append(0)
            row_d['value_gurobi'] = 0
          if gurobi_qubo_tte:
            row.append(np.round(gurobi_qubo_tte,4))
            row_d['gurobi_tte'] = np.round(gurobi_qubo_tte,4)
          else:
            row.append(0)
            row_d['gurobi_tte'] = 0

        report_file_obj = open(os.path.join(report_filename),'a+')
        report_file_obj.write('__'.join(map(str,row))+'\n')
        report_file_obj.close()
        table_contents.append(row)

        with open(report_filename_csv, mode='a', newline='') as report_file:
          writer = csv.DictWriter(report_file, fieldnames=row_d.keys())
          writer.writerow(row_d)

        print('\n')
# Out:
# seed: 333, number of agents: 2
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-25
# gurobi_qubo_value -100.0
# gurobi_qubo_tte: 0.07140135765075684
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 2
# gurobi_qubo_value -100.0
# gurobi_qubo_tte: 0.009998559951782227
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 3
# gurobi_qubo_value -100.0
# gurobi_qubo_tte: 0.014723539352416992
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 3
# gurobi_qubo_value -100.0
# gurobi_qubo_tte: 0.013986825942993164
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 4
# gurobi_qubo_value -147.85000000000002
# gurobi_qubo_tte: 0.021225690841674805
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 4
# gurobi_qubo_value -147.85
# gurobi_qubo_tte: 0.019003629684448242
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 5
# gurobi_qubo_value -71.29
# gurobi_qubo_tte: 0.02400517463684082
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 5
# gurobi_qubo_value -147.85
# gurobi_qubo_tte: 0.018998384475708008
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 6
# gurobi_qubo_value -20.46
# gurobi_qubo_tte: 0.025997161865234375
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 6
# gurobi_qubo_value -147.85000000000002
# gurobi_qubo_tte: 0.025506973266601562
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 7
# gurobi_qubo_value -22.91
# gurobi_qubo_tte: 0.10483145713806152
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 7
# gurobi_qubo_value -147.85000000000002
# gurobi_qubo_tte: 0.02999711036682129
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 8
# gurobi_qubo_value -13.850000000000016
# gurobi_qubo_tte: 0.03751230239868164
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 8
# gurobi_qubo_value -147.85
# gurobi_qubo_tte: 0.036913156509399414
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 9
# gurobi_qubo_value -188.72
# gurobi_qubo_tte: 0.08581876754760742
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 9
# gurobi_qubo_value -147.85000000000005
# gurobi_qubo_tte: 0.040795326232910156
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 10
# gurobi_qubo_value -121.02000000000007
# gurobi_qubo_tte: 0.1242988109588623
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 10
# gurobi_qubo_value -147.85000000000005
# gurobi_qubo_tte: 0.04804277420043945
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 11
# gurobi_qubo_value -216.07999999999996
# gurobi_qubo_tte: 0.10538125038146973
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 11
# gurobi_qubo_value -189.16000000000003
# gurobi_qubo_tte: 0.05599665641784668
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 12
# gurobi_qubo_value -294.16
# gurobi_qubo_tte: 0.1403212547302246
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 12
# gurobi_qubo_value -189.16000000000003
# gurobi_qubo_tte: 0.06676673889160156
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 13
# gurobi_qubo_value -297.77000000000004
# gurobi_qubo_tte: 0.16093945503234863
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 13
# gurobi_qubo_value -189.16000000000008
# gurobi_qubo_tte: 0.07382774353027344
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 14
# gurobi_qubo_value -364.4900000000003
# gurobi_qubo_tte: 0.1904289722442627
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 14
# gurobi_qubo_value -189.16000000000003
# gurobi_qubo_tte: 0.0868227481842041
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 15
# gurobi_qubo_value -539.22
# gurobi_qubo_tte: 0.18287420272827148
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 15
# gurobi_qubo_value -189.1599999999999
# gurobi_qubo_tte: 0.09690332412719727
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 16
# gurobi_qubo_value -351.1300000000001
# gurobi_qubo_tte: 0.24515032768249512
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 16
# gurobi_qubo_value -189.16
# gurobi_qubo_tte: 0.10903096199035645
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 17
# gurobi_qubo_value -500.0099999999999
# gurobi_qubo_tte: 0.22400426864624023
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 17
# gurobi_qubo_value -189.16000000000003
# gurobi_qubo_tte: 0.11595940589904785
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 18
# gurobi_qubo_value -523.2000000000003
# gurobi_qubo_tte: 0.28244900703430176
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 18
# gurobi_qubo_value -253.06
# gurobi_qubo_tte: 0.13403916358947754
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 19
# gurobi_qubo_value -558.2
# gurobi_qubo_tte: 0.3035850524902344
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 19
# gurobi_qubo_value -253.06
# gurobi_qubo_tte: 0.1409308910369873
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 20
# gurobi_qubo_value -652.0599999999997
# gurobi_qubo_tte: 0.38734889030456543
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 20
# gurobi_qubo_value -340.43000000000006
# gurobi_qubo_tte: 0.15747332572937012
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 21
# gurobi_qubo_value -917.31
# gurobi_qubo_tte: 0.5857360363006592
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 21
# gurobi_qubo_value -406.37000000000006
# gurobi_qubo_tte: 0.17442584037780762
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 22
# gurobi_qubo_value -918.32
# gurobi_qubo_tte: 0.36705923080444336
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 22
# gurobi_qubo_value -450.7200000000002
# gurobi_qubo_tte: 0.19151616096496582
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 23
# gurobi_qubo_value -1251.0600000000002
# gurobi_qubo_tte: 0.3728947639465332
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 23
# gurobi_qubo_value -450.72
# gurobi_qubo_tte: 0.20125818252563477
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 24
# gurobi_qubo_value -1665.1
# gurobi_qubo_tte: 0.40746259689331055
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 24
# gurobi_qubo_value -450.72000000000014
# gurobi_qubo_tte: 0.21537089347839355
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 25
# gurobi_qubo_value -1374.3100000000002
# gurobi_qubo_tte: 0.5520665645599365
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 25
# gurobi_qubo_value -450.72000000000014
# gurobi_qubo_tte: 0.2400217056274414
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 26
# gurobi_qubo_value -1194.02
# gurobi_qubo_tte: 0.6058480739593506
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 26
# gurobi_qubo_value -450.72
# gurobi_qubo_tte: 0.25461435317993164
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 27
# gurobi_qubo_value -1418.1899999999998
# gurobi_qubo_tte: 0.5770411491394043
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 27
# gurobi_qubo_value -450.7200000000001
# gurobi_qubo_tte: 0.27523112297058105
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 28
# gurobi_qubo_value -1281.4
# gurobi_qubo_tte: 0.7309980392456055
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 28
# gurobi_qubo_value -450.7200000000001
# gurobi_qubo_tte: 0.2935154438018799
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 29
# gurobi_qubo_value -1918.6000000000004
# gurobi_qubo_tte: 0.644120454788208
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 29
# gurobi_qubo_value -549.86
# gurobi_qubo_tte: 0.3075215816497803
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 30
# gurobi_qubo_value -1800.7899999999997
# gurobi_qubo_tte: 0.8926773071289062
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 30
# gurobi_qubo_value -549.86
# gurobi_qubo_tte: 0.32393503189086914
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 31
# gurobi_qubo_value -1910.5099999999998
# gurobi_qubo_tte: 0.8133938312530518
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 31
# gurobi_qubo_value -625.98
# gurobi_qubo_tte: 0.3355276584625244
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 32
# gurobi_qubo_value -1810.77
# gurobi_qubo_tte: 1.2047886848449707
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 32
# gurobi_qubo_value -625.9800000000001
# gurobi_qubo_tte: 0.475968599319458
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 33
# gurobi_qubo_value -2576.1499999999996
# gurobi_qubo_tte: 0.8155672550201416
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 33
# gurobi_qubo_value -625.9799999999999
# gurobi_qubo_tte: 0.36937808990478516
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 34
# gurobi_qubo_value -2270.75
# gurobi_qubo_tte: 1.0307543277740479
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 34
# gurobi_qubo_value -643.0400000000001
# gurobi_qubo_tte: 0.3938028812408447
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 35
# gurobi_qubo_value -2460.84
# gurobi_qubo_tte: 1.0805721282958984
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 35
# gurobi_qubo_value -683.72
# gurobi_qubo_tte: 0.43190622329711914
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 36
# gurobi_qubo_value -2914.9700000000003
# gurobi_qubo_tte: 1.3933165073394775
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 36
# gurobi_qubo_value -683.72
# gurobi_qubo_tte: 0.4580364227294922
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 37
# gurobi_qubo_value -3288.1700000000005
# gurobi_qubo_tte: 1.2189807891845703
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 37
# gurobi_qubo_value -683.7199999999998
# gurobi_qubo_tte: 0.4609954357147217
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 38
# gurobi_qubo_value -3096.71
# gurobi_qubo_tte: 1.461550235748291
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 38
# gurobi_qubo_value -689.23
# gurobi_qubo_tte: 0.4849686622619629
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 39
# gurobi_qubo_value -3001.1500000000005
# gurobi_qubo_tte: 1.8322463035583496
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 39
# gurobi_qubo_value -702.8100000000001
# gurobi_qubo_tte: 0.5140652656555176
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 40
# gurobi_qubo_value -3271.0600000000004
# gurobi_qubo_tte: 1.4658942222595215
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 40
# gurobi_qubo_value -702.8100000000001
# gurobi_qubo_tte: 0.5518293380737305
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 41
# gurobi_qubo_value -3625.5200000000004
# gurobi_qubo_tte: 1.606097936630249
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 41
# gurobi_qubo_value -702.8100000000002
# gurobi_qubo_tte: 0.636519193649292
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 42
# gurobi_qubo_value -2985.4800000000005
# gurobi_qubo_tte: 4.071683168411255
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 42
# gurobi_qubo_value -702.8100000000001
# gurobi_qubo_tte: 0.5919325351715088
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 43
# gurobi_qubo_value -3215.6200000000003
# gurobi_qubo_tte: 1.8314330577850342
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 43
# gurobi_qubo_value -702.8100000000001
# gurobi_qubo_tte: 0.6094965934753418
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 44
# gurobi_qubo_value -3611.730000000001
# gurobi_qubo_tte: 2.360319137573242
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 44
# gurobi_qubo_value -786.9299999999998
# gurobi_qubo_tte: 0.6382427215576172
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 45
# gurobi_qubo_value -3536.09
# gurobi_qubo_tte: 4.8944432735443115
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 45
# gurobi_qubo_value -883.59
# gurobi_qubo_tte: 0.6715741157531738
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 46
# gurobi_qubo_value -3731.53
# gurobi_qubo_tte: 5.161875486373901
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 46
# gurobi_qubo_value -978.91
# gurobi_qubo_tte: 0.6979875564575195
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 47
# gurobi_qubo_value -4302.58
# gurobi_qubo_tte: 2.554689645767212
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 47
# gurobi_qubo_value -978.9099999999995
# gurobi_qubo_tte: 0.7915821075439453
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 48
# gurobi_qubo_value -4532.0
# gurobi_qubo_tte: 5.537170648574829
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 48
# gurobi_qubo_value -1040.4
# gurobi_qubo_tte: 0.7734618186950684
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 49
# gurobi_qubo_value -4761.82
# gurobi_qubo_tte: 5.3935205936431885
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 49
# gurobi_qubo_value -1113.6699999999998
# gurobi_qubo_tte: 0.8076324462890625
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 50
# gurobi_qubo_value -4660.22
# gurobi_qubo_tte: 3.2811880111694336
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 50
# gurobi_qubo_value -1116.93
# gurobi_qubo_tte: 0.8380515575408936
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 51
# gurobi_qubo_value -4921.77
# gurobi_qubo_tte: 5.7723565101623535
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 51
# gurobi_qubo_value -1159.8099999999995
# gurobi_qubo_tte: 9.903223037719727
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 52
# gurobi_qubo_value -5231.8099999999995
# gurobi_qubo_tte: 8.337283849716187
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 52
# gurobi_qubo_value -1159.81
# gurobi_qubo_tte: 0.931812047958374
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 53
# gurobi_qubo_value -5514.42
# gurobi_qubo_tte: 7.21155571937561
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 53
# gurobi_qubo_value -1188.29
# gurobi_qubo_tte: 0.955721378326416
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 54
# gurobi_qubo_value -5258.099999999999
# gurobi_qubo_tte: 11.434173345565796
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 54
# gurobi_qubo_value -1197.3100000000002
# gurobi_qubo_tte: 0.9842226505279541
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 55
# gurobi_qubo_value -5206.010000000001
# gurobi_qubo_tte: 13.919877767562866
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 55
# gurobi_qubo_value -1208.9199999999998
# gurobi_qubo_tte: 1.0384902954101562
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 56
# gurobi_qubo_value -5161.3
# gurobi_qubo_tte: 13.314172267913818
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 56
# gurobi_qubo_value -1208.92
# gurobi_qubo_tte: 1.082852840423584
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 57
# gurobi_qubo_value -5065.030000000001
# gurobi_qubo_tte: 20.508836269378662
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 57
# gurobi_qubo_value -1208.92
# gurobi_qubo_tte: 1.1320502758026123
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 58
# gurobi_qubo_value -5685.570000000001
# gurobi_qubo_tte: 12.159114360809326
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 58
# gurobi_qubo_value -1208.9199999999998
# gurobi_qubo_tte: 1.2164113521575928
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 59
# gurobi_qubo_value -5609.279999999999
# gurobi_qubo_tte: 26.139312267303467
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 59
# gurobi_qubo_value -1232.1399999999999
# gurobi_qubo_tte: 1.9256041049957275
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 60
# gurobi_qubo_value -6189.969999999998
# gurobi_qubo_tte: 35.61655139923096
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 60
# gurobi_qubo_value -1232.1399999999999
# gurobi_qubo_tte: 1.7269961833953857
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 61
# gurobi_qubo_value -6106.0199999999995
# gurobi_qubo_tte: 47.05800437927246
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 61
# gurobi_qubo_value -1232.1400000000003
# gurobi_qubo_tte: 1.4502625465393066
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 62
# gurobi_qubo_value -7178.740000000002
# gurobi_qubo_tte: 18.029402017593384
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 62
# gurobi_qubo_value -1232.1399999999999
# gurobi_qubo_tte: 1.4354050159454346
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 63
# gurobi_qubo_value -6286.659999999998
# gurobi_qubo_tte: 65.47723197937012
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 63
# gurobi_qubo_value -1232.1400000000003
# gurobi_qubo_tte: 1.391488790512085
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 64
# gurobi_qubo_value -6330.03
# gurobi_qubo_tte: 50.58962798118591
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 64
# gurobi_qubo_value -1232.14
# gurobi_qubo_tte: 1.6092967987060547
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 65
# gurobi_qubo_value -6751.66
# gurobi_qubo_tte: 65.95318245887756
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 65
# gurobi_qubo_value -1232.1400000000003
# gurobi_qubo_tte: 1.9864554405212402
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 66
# gurobi_qubo_value -6736.99
# gurobi_qubo_tte: 79.08652949333191
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 66
# gurobi_qubo_value -1232.1400000000003
# gurobi_qubo_tte: 1.5170459747314453
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 67
# gurobi_qubo_value -7599.43
# gurobi_qubo_tte: 48.71159505844116
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 67
# gurobi_qubo_value -1232.1400000000003
# gurobi_qubo_tte: 1.6147801876068115
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 68
# gurobi_qubo_value -7482.16
# gurobi_qubo_tte: 119.06406354904175
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 68
# gurobi_qubo_value -1272.9399999999996
# gurobi_qubo_tte: 1.7006421089172363
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 69
# gurobi_qubo_value -7813.300000000002
# gurobi_qubo_tte: 103.90409207344055
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 69
# gurobi_qubo_value -1272.9399999999998
# gurobi_qubo_tte: 1.7528188228607178
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 70
# gurobi_qubo_value -7778.75
# gurobi_qubo_tte: 335.44964361190796
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 70
# gurobi_qubo_value -1272.9400000000005
# gurobi_qubo_tte: 1.8387455940246582
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 71
# gurobi_qubo_value -8828.060000000001
# gurobi_qubo_tte: 89.20609545707703
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 71
# gurobi_qubo_value -1328.3300000000006
# gurobi_qubo_tte: 1.8167164325714111
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 72
# gurobi_qubo_value -8561.12
# gurobi_qubo_tte: 643.9449074268341
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 72
# gurobi_qubo_value -1328.3299999999997
# gurobi_qubo_tte: 1.850623369216919
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 73
# gurobi_qubo_value -9190.539999999999
# gurobi_qubo_tte: 345.7342140674591
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 73
# gurobi_qubo_value -1427.35
# gurobi_qubo_tte: 1.9895873069763184
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 74
# gurobi_qubo_value -10028.28
# gurobi_qubo_tte: 86.23820233345032
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 74
# gurobi_qubo_value -1427.3500000000004
# gurobi_qubo_tte: 1.9363312721252441
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 75
# gurobi_qubo_value -9533.149999999998
# gurobi_qubo_tte: 561.1337475776672
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 75
# gurobi_qubo_value -1480.1099999999997
# gurobi_qubo_tte: 2.007822275161743
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 76
# gurobi_qubo_value -9802.92
# gurobi_qubo_tte: 560.691059589386
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 76
# gurobi_qubo_value -1480.1100000000001
# gurobi_qubo_tte: 2.819890022277832
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 77
# gurobi_qubo_value -9723.499999999998
# gurobi_qubo_tte: 1372.0340168476105
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 77
# gurobi_qubo_value -1491.3000000000002
# gurobi_qubo_tte: 2.167173385620117
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 78
# gurobi_qubo_value -10735.300000000001
# gurobi_qubo_tte: 231.49547958374023
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 78
# gurobi_qubo_value -1507.68
# gurobi_qubo_tte: 2.188107967376709
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 79
# gurobi_qubo_value -10085.130000000001
# gurobi_qubo_tte: 1652.2728080749512
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 79
# gurobi_qubo_value -1519.0300000000002
# gurobi_qubo_tte: 3.135138988494873
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 80
# gurobi_qubo_value -10450.869999999997
# gurobi_qubo_tte: 1589.9230222702026
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 80
# gurobi_qubo_value -1563.3699999999997
# gurobi_qubo_tte: 2.3523411750793457
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 81
# gurobi_qubo_value -1602.8600000000001
# gurobi_qubo_tte: 2.3484346866607666
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 82
# gurobi_qubo_value -1602.86
# gurobi_qubo_tte: 2.514599323272705
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 83
# gurobi_qubo_value -1620.9599999999996
# gurobi_qubo_tte: 2.4423818588256836
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 84
# gurobi_qubo_value -1660.7200000000005
# gurobi_qubo_tte: 2.5393831729888916
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 85
# gurobi_qubo_value -1683.99
# gurobi_qubo_tte: 2.5391287803649902
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 86
# gurobi_qubo_value -1729.4499999999998
# gurobi_qubo_tte: 2.6855502128601074
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 87
# gurobi_qubo_value -1729.4499999999998
# gurobi_qubo_tte: 2.680079460144043
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 88
# gurobi_qubo_value -1729.4499999999996
# gurobi_qubo_tte: 2.8672826290130615
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 89
# gurobi_qubo_value -1729.4499999999998
# gurobi_qubo_tte: 2.868640899658203
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 90
# gurobi_qubo_value -1729.4499999999998
# gurobi_qubo_tte: 2.975268602371216
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 91
# gurobi_qubo_value -1782.4899999999998
# gurobi_qubo_tte: 13.003479957580566
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 92
# gurobi_qubo_value -1782.4899999999996
# gurobi_qubo_tte: 3.047131299972534
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 93
# gurobi_qubo_value -1842.6399999999996
# gurobi_qubo_tte: 3.058245897293091
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 94
# gurobi_qubo_value -1842.64
# gurobi_qubo_tte: 3.356147527694702
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 95
# gurobi_qubo_value -1845.95
# gurobi_qubo_tte: 3.629816770553589
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 96
# gurobi_qubo_value -1845.9499999999998
# gurobi_qubo_tte: 3.4433939456939697
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 97
# gurobi_qubo_value -1845.9499999999998
# gurobi_qubo_tte: 3.87914776802063
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 98
# gurobi_qubo_value -1845.9499999999998
# gurobi_qubo_tte: 3.6079838275909424
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 99
# gurobi_qubo_value -1899.0400000000002
# gurobi_qubo_tte: 4.092792749404907
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 100
# gurobi_qubo_value -1975.64
# gurobi_qubo_tte: 4.156840562820435
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 101
# gurobi_qubo_value -2046.53
# gurobi_qubo_tte: 4.0089123249053955
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 102
# gurobi_qubo_value -2130.4399999999996
# gurobi_qubo_tte: 3.7173824310302734
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 103
# gurobi_qubo_value -2130.44
# gurobi_qubo_tte: 3.7778496742248535
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 104
# gurobi_qubo_value -2215.79
# gurobi_qubo_tte: 4.141890048980713
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 105
# gurobi_qubo_value -2215.79
# gurobi_qubo_tte: 4.4936535358428955
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 106
# gurobi_qubo_value -2215.79
# gurobi_qubo_tte: 4.625006437301636
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 107
# gurobi_qubo_value -2282.6300000000006
# gurobi_qubo_tte: 4.741615056991577
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 108
# gurobi_qubo_value -2282.6299999999997
# gurobi_qubo_tte: 5.12746000289917
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 109
# gurobi_qubo_value -2282.63
# gurobi_qubo_tte: 4.827855110168457
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 110
# gurobi_qubo_value -2320.729999999999
# gurobi_qubo_tte: 4.7462780475616455
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 111
# gurobi_qubo_value -2405.97
# gurobi_qubo_tte: 4.809904336929321
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 112
# gurobi_qubo_value -2405.9700000000003
# gurobi_qubo_tte: 4.753046751022339
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 113
# gurobi_qubo_value -2502.9500000000003
# gurobi_qubo_tte: 15.71407961845398
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 114
# gurobi_qubo_value -2519.7999999999997
# gurobi_qubo_tte: 4.836244821548462
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 115
# gurobi_qubo_value -2589.06
# gurobi_qubo_tte: 4.71156907081604
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 116
# gurobi_qubo_value -2589.0599999999995
# gurobi_qubo_tte: 4.818935871124268
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 117
# gurobi_qubo_value -2589.0599999999995
# gurobi_qubo_tte: 4.922553539276123
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 118
# gurobi_qubo_value -2647.1699999999996
# gurobi_qubo_tte: 4.963059663772583
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 119
# gurobi_qubo_value -2647.17
# gurobi_qubo_tte: 5.043572425842285
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 120
# gurobi_qubo_value -2727.5300000000007
# gurobi_qubo_tte: 5.180965185165405
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 121
# gurobi_qubo_value -2788.1199999999994
# gurobi_qubo_tte: 5.2025721073150635
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 122
# gurobi_qubo_value -2788.12
# gurobi_qubo_tte: 5.2783589363098145
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 123
# gurobi_qubo_value -2835.08
# gurobi_qubo_tte: 5.389829635620117
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 124
# gurobi_qubo_value -2835.08
# gurobi_qubo_tte: 5.418497800827026
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 125
# gurobi_qubo_value -2835.080000000001
# gurobi_qubo_tte: 5.61817479133606
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 126
# gurobi_qubo_value -2835.0800000000004
# gurobi_qubo_tte: 5.824292182922363
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 127
# gurobi_qubo_value -2876.3499999999995
# gurobi_qubo_tte: 5.7289814949035645
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 128
# gurobi_qubo_value -2909.3300000000004
# gurobi_qubo_tte: 5.842481851577759
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 129
# gurobi_qubo_value -2909.3300000000004
# gurobi_qubo_tte: 5.998267650604248
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 130
# gurobi_qubo_value -2909.3300000000004
# gurobi_qubo_tte: 6.062552213668823
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 131
# gurobi_qubo_value -2985.58
# gurobi_qubo_tte: 6.228086471557617
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 132
# gurobi_qubo_value -3062.6899999999996
# gurobi_qubo_tte: 18.15409755706787
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 133
# gurobi_qubo_value -3108.1400000000003
# gurobi_qubo_tte: 6.303978443145752
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 134
# gurobi_qubo_value -3108.1400000000003
# gurobi_qubo_tte: 6.429906368255615
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 135
# gurobi_qubo_value -3160.55
# gurobi_qubo_tte: 6.497051954269409
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 136
# gurobi_qubo_value -3178.5299999999993
# gurobi_qubo_tte: 6.651164770126343
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 137
# gurobi_qubo_value -3178.5299999999993
# gurobi_qubo_tte: 6.717443466186523
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 138
# gurobi_qubo_value -3178.53
# gurobi_qubo_tte: 6.766735792160034
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 139
# gurobi_qubo_value -3191.6600000000008
# gurobi_qubo_tte: 6.825446128845215
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 140
# gurobi_qubo_value -3237.2100000000005
# gurobi_qubo_tte: 6.9769370555877686
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 141
# gurobi_qubo_value -3237.21
# gurobi_qubo_tte: 7.073426008224487
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 142
# gurobi_qubo_value -3237.2100000000005
# gurobi_qubo_tte: 7.24088978767395
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 143
# gurobi_qubo_value -3237.2099999999996
# gurobi_qubo_tte: 7.304053068161011
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 144
# gurobi_qubo_value -3335.750000000001
# gurobi_qubo_tte: 7.296846389770508
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 145
# gurobi_qubo_value -3335.75
# gurobi_qubo_tte: 7.428662061691284
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 146
# gurobi_qubo_value -3335.7499999999995
# gurobi_qubo_tte: 7.502761602401733
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 147
# gurobi_qubo_value -3371.4700000000003
# gurobi_qubo_tte: 7.830411434173584
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 148
# gurobi_qubo_value -3371.4700000000003
# gurobi_qubo_tte: 7.824629068374634
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 149
# gurobi_qubo_value -3414.199999999999
# gurobi_qubo_tte: 8.138434171676636
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 150
# gurobi_qubo_value -3448.31
# gurobi_qubo_tte: 21.583205938339233
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 151
# gurobi_qubo_value -3500.48
# gurobi_qubo_tte: 8.155531406402588
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 152
# gurobi_qubo_value -3500.4799999999996
# gurobi_qubo_tte: 8.306966781616211
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 153
# gurobi_qubo_value -3567.08
# gurobi_qubo_tte: 8.42995023727417
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 154
# gurobi_qubo_value -3567.08
# gurobi_qubo_tte: 8.592385530471802
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 155
# gurobi_qubo_value -3651.7000000000003
# gurobi_qubo_tte: 8.690223455429077
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 156
# gurobi_qubo_value -3651.6999999999994
# gurobi_qubo_tte: 8.839892625808716
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 157
# gurobi_qubo_value -3651.7
# gurobi_qubo_tte: 8.839885473251343
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 158
# gurobi_qubo_value -3651.7
# gurobi_qubo_tte: 8.913501501083374
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 159
# gurobi_qubo_value -3678.1299999999997
# gurobi_qubo_tte: 9.310400485992432
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 160
# gurobi_qubo_value -3678.1300000000006
# gurobi_qubo_tte: 9.2313711643219
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 161
# gurobi_qubo_value -3678.1299999999997
# gurobi_qubo_tte: 9.207818508148193
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 162
# gurobi_qubo_value -3727.9399999999996
# gurobi_qubo_tte: 9.37533187866211
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 163
# gurobi_qubo_value -3740.53
# gurobi_qubo_tte: 9.641410112380981
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 164
# gurobi_qubo_value -3740.5299999999997
# gurobi_qubo_tte: 10.064589262008667
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 165
# gurobi_qubo_value -3786.65
# gurobi_qubo_tte: 10.06593132019043
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 166
# gurobi_qubo_value -3786.65
# gurobi_qubo_tte: 10.203684568405151
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 167
# gurobi_qubo_value -3786.6499999999996
# gurobi_qubo_tte: 10.17446255683899
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 168
# gurobi_qubo_value -3786.65
# gurobi_qubo_tte: 28.685792684555054
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 169
# gurobi_qubo_value -3786.649999999999
# gurobi_qubo_tte: 13.613000631332397
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 170
# gurobi_qubo_value -3830.51
# gurobi_qubo_tte: 14.141627073287964
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 171
# gurobi_qubo_value -3830.5099999999998
# gurobi_qubo_tte: 10.99947452545166
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 172
# gurobi_qubo_value -3830.5099999999998
# gurobi_qubo_tte: 10.471566677093506
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 173
# gurobi_qubo_value -3887.66
# gurobi_qubo_tte: 10.553893327713013
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 174
# gurobi_qubo_value -3887.659999999999
# gurobi_qubo_tte: 10.742157459259033
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 175
# gurobi_qubo_value -3942.3
# gurobi_qubo_tte: 10.890289545059204
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 176
# gurobi_qubo_value -3942.3
# gurobi_qubo_tte: 10.93468165397644
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 177
# gurobi_qubo_value -3942.2999999999997
# gurobi_qubo_tte: 11.826502799987793
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 178
# gurobi_qubo_value -3968.5399999999995
# gurobi_qubo_tte: 11.072158336639404
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 179
# gurobi_qubo_value -4009.2400000000002
# gurobi_qubo_tte: 11.225696086883545
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 180
# gurobi_qubo_value -4037.7000000000007
# gurobi_qubo_tte: 11.32439661026001
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 181
# gurobi_qubo_value -4037.6999999999994
# gurobi_qubo_tte: 12.01457405090332
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 182
# gurobi_qubo_value -4037.7000000000003
# gurobi_qubo_tte: 11.8691565990448
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 183
# gurobi_qubo_value -4037.7000000000003
# gurobi_qubo_tte: 12.007572412490845
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 184
# gurobi_qubo_value -4120.2699999999995
# gurobi_qubo_tte: 11.937451362609863
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 185
# gurobi_qubo_value -4143.539999999999
# gurobi_qubo_tte: 12.071505784988403
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 186
# gurobi_qubo_value -4143.54
# gurobi_qubo_tte: 138.9893834590912
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 187
# gurobi_qubo_value -4143.54
# gurobi_qubo_tte: 12.449352741241455
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 188
# gurobi_qubo_value -4201.740000000001
# gurobi_qubo_tte: 12.747440099716187
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 189
# gurobi_qubo_value -4285.15
# gurobi_qubo_tte: 12.580661296844482
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 190
# gurobi_qubo_value -4285.15
# gurobi_qubo_tte: 12.722782135009766
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 191
# gurobi_qubo_value -4285.149999999999
# gurobi_qubo_tte: 13.782761812210083
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 192
# gurobi_qubo_value -4285.15
# gurobi_qubo_tte: 14.683536529541016
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 193
# gurobi_qubo_value -4332.43
# gurobi_qubo_tte: 13.405372858047485
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 194
# gurobi_qubo_value -4359.470000000001
# gurobi_qubo_tte: 13.227733373641968
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 195
# gurobi_qubo_value -4359.470000000001
# gurobi_qubo_tte: 13.478935718536377
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 196
# gurobi_qubo_value -4403.04
# gurobi_qubo_tte: 13.70388126373291
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 197
# gurobi_qubo_value -4403.039999999999
# gurobi_qubo_tte: 18.04937767982483
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 198
# gurobi_qubo_value -4403.040000000001
# gurobi_qubo_tte: 15.46489405632019
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 199
# gurobi_qubo_value -4403.039999999999
# gurobi_qubo_tte: 15.47939157485962
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 200
# gurobi_qubo_value -4403.04
# gurobi_qubo_tte: 14.972109317779541
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 201
# gurobi_qubo_value -4403.04
# gurobi_qubo_tte: 16.072240591049194
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 202
# gurobi_qubo_value -4452.000000000001
# gurobi_qubo_tte: 15.083879709243774
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 203
# gurobi_qubo_value -4459.8899999999985
# gurobi_qubo_tte: 14.576470613479614
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 204
# gurobi_qubo_value -4549.900000000002
# gurobi_qubo_tte: 290.3630220890045
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 205
# gurobi_qubo_value -4549.900000000001
# gurobi_qubo_tte: 16.431748390197754
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 206
# gurobi_qubo_value -4644.45
# gurobi_qubo_tte: 15.670790433883667
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 207
# gurobi_qubo_value -4693.72
# gurobi_qubo_tte: 15.046968936920166
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 208
# gurobi_qubo_value -4693.719999999999
# gurobi_qubo_tte: 15.134946823120117
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 209
# gurobi_qubo_value -4754.22
# gurobi_qubo_tte: 15.727643966674805
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 210
# gurobi_qubo_value -4829.859999999999
# gurobi_qubo_tte: 16.33149766921997
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 211
# gurobi_qubo_value -4829.859999999999
# gurobi_qubo_tte: 16.2548189163208
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 212
# gurobi_qubo_value -4829.86
# gurobi_qubo_tte: 15.779361724853516
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 213
# gurobi_qubo_value -4841.490000000001
# gurobi_qubo_tte: 15.989927768707275
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 214
# gurobi_qubo_value -4850.88
# gurobi_qubo_tte: 16.00632667541504
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 215
# gurobi_qubo_value -4929.259999999999
# gurobi_qubo_tte: 16.178365468978882
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 216
# gurobi_qubo_value -4956.879999999999
# gurobi_qubo_tte: 16.16098380088806
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 217
# gurobi_qubo_value -4956.879999999999
# gurobi_qubo_tte: 16.655778884887695
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 218
# gurobi_qubo_value -5047.909999999999
# gurobi_qubo_tte: 16.64067578315735
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 219
# gurobi_qubo_value -5047.91
# gurobi_qubo_tte: 16.835362195968628
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 220
# gurobi_qubo_value -5048.13
# gurobi_qubo_tte: 17.164057970046997
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 221
# gurobi_qubo_value -5143.299999999999
# gurobi_qubo_tte: 17.69236159324646
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 222
# gurobi_qubo_value -5219.04
# gurobi_qubo_tte: 17.603472471237183
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 223
# gurobi_qubo_value -5267.089999999999
# gurobi_qubo_tte: 498.43959641456604
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 224
# gurobi_qubo_value -5282.380000000001
# gurobi_qubo_tte: 18.130444526672363
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 225
# gurobi_qubo_value -5349.110000000001
# gurobi_qubo_tte: 18.01956605911255
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 226
# gurobi_qubo_value -5418.77
# gurobi_qubo_tte: 18.236409187316895
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 227
# gurobi_qubo_value -5418.7699999999995
# gurobi_qubo_tte: 20.86920928955078
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 228
# gurobi_qubo_value -5465.840000000001
# gurobi_qubo_tte: 20.68834161758423
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 229
# gurobi_qubo_value -5465.84
# gurobi_qubo_tte: 19.908472537994385
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 230
# gurobi_qubo_value -5465.84
# gurobi_qubo_tte: 19.12869930267334
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 231
# gurobi_qubo_value -5482.85
# gurobi_qubo_tte: 19.123604774475098
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 232
# gurobi_qubo_value -5482.850000000001
# gurobi_qubo_tte: 19.143332481384277
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 233
# gurobi_qubo_value -5582.299999999999
# gurobi_qubo_tte: 19.69032335281372
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 234
# gurobi_qubo_value -5609.500000000001
# gurobi_qubo_tte: 19.519182205200195
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 235
# gurobi_qubo_value -5668.2699999999995
# gurobi_qubo_tte: 19.76869821548462
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 236
# gurobi_qubo_value -5668.270000000001
# gurobi_qubo_tte: 19.818394422531128
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 237
# gurobi_qubo_value -5668.269999999999
# gurobi_qubo_tte: 20.659528493881226
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 238
# gurobi_qubo_value -5709.589999999999
# gurobi_qubo_tte: 19.977784395217896
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 239
# gurobi_qubo_value -5709.59
# gurobi_qubo_tte: 20.221999645233154
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 240
# gurobi_qubo_value -5779.11
# gurobi_qubo_tte: 20.605319261550903
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 241
# gurobi_qubo_value -5779.110000000001
# gurobi_qubo_tte: 20.524470329284668
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 242
# gurobi_qubo_value -5779.11
# gurobi_qubo_tte: 22.129333972930908
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 243
# gurobi_qubo_value -5793.16
# gurobi_qubo_tte: 21.33214783668518
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 244
# gurobi_qubo_value -5793.160000000001
# gurobi_qubo_tte: 639.4403703212738
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 245
# gurobi_qubo_value -5793.16
# gurobi_qubo_tte: 21.615001678466797
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 246
# gurobi_qubo_value -5878.5199999999995
# gurobi_qubo_tte: 21.794321537017822
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 247
# gurobi_qubo_value -5878.519999999999
# gurobi_qubo_tte: 21.592930793762207
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 248
# gurobi_qubo_value -5878.520000000001
# gurobi_qubo_tte: 21.72827649116516
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 249
# gurobi_qubo_value -5950.150000000001
# gurobi_qubo_tte: 22.62783432006836
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 250
# gurobi_qubo_value -5950.150000000001
# gurobi_qubo_tte: 22.15766215324402
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 251
# gurobi_qubo_value -5950.15
# gurobi_qubo_tte: 22.391051530838013
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 252
# gurobi_qubo_value -6046.989999999999
# gurobi_qubo_tte: 22.35498833656311
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 253
# gurobi_qubo_value -6085.059999999999
# gurobi_qubo_tte: 22.776676416397095
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 254
# gurobi_qubo_value -6085.0599999999995
# gurobi_qubo_tte: 22.8954176902771
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 255
# gurobi_qubo_value -6146.97
# gurobi_qubo_tte: 23.156997442245483
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 256
# gurobi_qubo_value -6220.5
# gurobi_qubo_tte: 23.325377702713013
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 257
# gurobi_qubo_value -6220.500000000001
# gurobi_qubo_tte: 23.531925201416016
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 258
# gurobi_qubo_value -6220.5
# gurobi_qubo_tte: 23.682987689971924
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 259
# gurobi_qubo_value -6220.5
# gurobi_qubo_tte: 24.146370887756348
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 260
# gurobi_qubo_value -6220.499999999999
# gurobi_qubo_tte: 24.771373748779297
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 261
# gurobi_qubo_value -6220.500000000001
# gurobi_qubo_tte: 24.218657732009888
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 262
# gurobi_qubo_value -6220.499999999999
# gurobi_qubo_tte: 24.805216073989868
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 263
# gurobi_qubo_value -6292.830000000001
# gurobi_qubo_tte: 27.502223014831543
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 264
# gurobi_qubo_value -6301.64
# gurobi_qubo_tte: 24.687568426132202
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 265
# gurobi_qubo_value -6344.93
# gurobi_qubo_tte: 1061.7177572250366
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 266
# gurobi_qubo_value -6345.969999999999
# gurobi_qubo_tte: 25.37494945526123
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 267
# gurobi_qubo_value -6348.330000000001
# gurobi_qubo_tte: 24.942418813705444
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 268
# gurobi_qubo_value -6348.33
# gurobi_qubo_tte: 26.026236295700073
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 269
# gurobi_qubo_value -6400.049999999999
# gurobi_qubo_tte: 39.461318254470825
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 270
# gurobi_qubo_value -6400.049999999998
# gurobi_qubo_tte: 29.00620150566101
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 271
# gurobi_qubo_value -6443.03
# gurobi_qubo_tte: 25.93150758743286
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 272
# gurobi_qubo_value -6491.08
# gurobi_qubo_tte: 26.133458852767944
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 273
# gurobi_qubo_value -6530.03
# gurobi_qubo_tte: 26.516618967056274
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 274
# gurobi_qubo_value -6550.29
# gurobi_qubo_tte: 26.492735862731934
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 275
# gurobi_qubo_value -6550.290000000001
# gurobi_qubo_tte: 27.08070397377014
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 276
# gurobi_qubo_value -6599.36
# gurobi_qubo_tte: 26.940094709396362
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 277
# gurobi_qubo_value -6599.359999999999
# gurobi_qubo_tte: 27.034712553024292
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 278
# gurobi_qubo_value -6599.36
# gurobi_qubo_tte: 27.40631413459778
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 279
# gurobi_qubo_value -6666.58
# gurobi_qubo_tte: 27.621590614318848
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 280
# gurobi_qubo_value -6691.930000000001
# gurobi_qubo_tte: 27.862407684326172
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 281
# gurobi_qubo_value -6691.93
# gurobi_qubo_tte: 28.089178800582886
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 282
# gurobi_qubo_value -6694.44
# gurobi_qubo_tte: 28.501347064971924
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 283
# gurobi_qubo_value -6756.26
# gurobi_qubo_tte: 28.438196897506714
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 284
# gurobi_qubo_value -6788.24
# gurobi_qubo_tte: 28.529535055160522
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 285
# gurobi_qubo_value -6794.4
# gurobi_qubo_tte: 29.084986686706543
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 286
# gurobi_qubo_value -6794.4
# gurobi_qubo_tte: 30.154778718948364
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 287
# gurobi_qubo_value -6794.399999999999
# gurobi_qubo_tte: 2028.994268655777
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 288
# gurobi_qubo_value -6794.4
# gurobi_qubo_tte: 32.78262710571289
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 289
# gurobi_qubo_value -6835.780000000001
# gurobi_qubo_tte: 29.76865839958191
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 290
# gurobi_qubo_value -6835.779999999999
# gurobi_qubo_tte: 30.09397792816162
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 291
# gurobi_qubo_value -6835.780000000002
# gurobi_qubo_tte: 30.59409236907959
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 292
# gurobi_qubo_value -6835.779999999999
# gurobi_qubo_tte: 30.873437881469727
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 293
# gurobi_qubo_value -6835.780000000002
# gurobi_qubo_tte: 31.51426672935486
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 294
# gurobi_qubo_value -6863.480000000001
# gurobi_qubo_tte: 31.05335545539856
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 295
# gurobi_qubo_value -6863.479999999999
# gurobi_qubo_tte: 32.67906665802002
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 296
# gurobi_qubo_value -6929.720000000001
# gurobi_qubo_tte: 31.61549997329712
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 297
# gurobi_qubo_value -7002.920000000001
# gurobi_qubo_tte: 31.403459787368774
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 298
# gurobi_qubo_value -7013.089999999999
# gurobi_qubo_tte: 31.636350870132446
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 299
# gurobi_qubo_value -7083.800000000001
# gurobi_qubo_tte: 32.04852080345154
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 300
# gurobi_qubo_value -7162.0199999999995
# gurobi_qubo_tte: 32.93437957763672
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 301
# gurobi_qubo_value -7178.39
# gurobi_qubo_tte: 33.28094124794006
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 302
# gurobi_qubo_value -7265.12
# gurobi_qubo_tte: 32.8482027053833
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 303
# gurobi_qubo_value -7291.53
# gurobi_qubo_tte: 38.35762119293213
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 304
# gurobi_qubo_value -7291.530000000002
# gurobi_qubo_tte: 34.77004623413086
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 305
# gurobi_qubo_value -7340.179999999999
# gurobi_qubo_tte: 33.56704545021057
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 306
# gurobi_qubo_value -7340.18
# gurobi_qubo_tte: 33.74572563171387
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 307
# gurobi_qubo_value -7409.4000000000015
# gurobi_qubo_tte: 33.8776741027832
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 308
# gurobi_qubo_value -7409.400000000001
# gurobi_qubo_tte: 34.69311785697937
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 309
# gurobi_qubo_value -7409.400000000001
# gurobi_qubo_tte: 34.409294843673706
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 310
# gurobi_qubo_value -7409.4
# gurobi_qubo_tte: 34.958147048950195
# GUROBI QUBO DONE!
#
#
# seed: 333, number of agents: 311
